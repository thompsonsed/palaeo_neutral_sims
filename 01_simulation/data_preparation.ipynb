# %% [markdown]
# # DATA PREPARATION FOR SPATIALLY-EXPLICIT NEUTRAL MODELS
#
# This file requires
# - scotese shape files for continental boundaries at different times (280, 320 and 340 mya)
# - info_per_pcoords.csv for location data for each fragment (output of R script)
#
# # This file outputs
# - Raster files for each interval for continental extents
# - Raster files for sampling regimes across the world
# - Shapefiles for all sites at each interval

# %%
import math
import numpy as np
import os
import pandas as pd

from data_preparation import rasterize, extract_from_shapefile, \
	create_shapefile_from_points, find_distance_lat_long, randomly_clear_landscape, add_masks
from pycoalescence import Map

# %%
# Data set up
# set this to the path to the data directory. Everything else should work from that
# data_directory = "/Volumes/Seagate 3TB/Paleo/Data"
data_directory = "/run/media/sam/Media/Paleo/Data/"
data_directory_local = "../MainSimulationR/input/"
# the list of folders containing the shape files to convert to raster
folder_list = ["340m", "320m", "280m"]
interval_list = ["permian", "early_carboniferous", "late_carboniferous"]

# %%
# This extracts the continental shapes from the shapefiles into a new file, and then converts it to a
# raster.
for folder in folder_list:
	file_path = os.path.join(data_directory, "scotese", folder, "wcnt.shp")
	file_path_altered = os.path.join(data_directory, "scotese", folder, "wcnt_altered.shp")
	if not os.path.exists(file_path):
		raise IOError("file {} does not exist".format(file_path))
	# Drop all features from the shapefile which don't match "CM" field
	extract_from_shapefile(file_path, file_path_altered, field="TYPE", field_value="CM")
	# Now convert our altered shapefile to a raster
	output_path = os.path.join(data_directory, "paleo_maps", "{}.tif".format(folder))
	rasterize(file_path_altered, output_path, pixel_size=0.01)

# %%
# now rename the three files in question
os.rename(os.path.join(data_directory, "paleo_maps", "320m.tif"), 
		  os.path.join(data_directory, "paleo_maps", "late_carboniferous.tif"))
os.rename(os.path.join(data_directory, "paleo_maps", "340m.tif"), 
		  os.path.join(data_directory, "paleo_maps", "early_carboniferous.tif"))
os.rename(os.path.join(data_directory, "paleo_maps", "280m.tif"), 
		  os.path.join(data_directory, "paleo_maps", "permian.tif"))

# %%
# Import the fragment coordinates from csv.
info_per_pcoord = pd.read_csv(os.path.join(data_directory_local, "info_per_pcoord.csv"))
info_per_pcoord['lat'] = np.NaN
info_per_pcoord['long'] = np.NaN
# split into lat and long for shapefile
for index, row in info_per_pcoord.iterrows():
	lat, long = row["pcoords"].split(",")
	info_per_pcoord.loc[index, 'lat'] = pd.to_numeric(lat) # plus some small modifier\n",
	info_per_pcoord.loc[index, 'long'] = pd.to_numeric(long)

# %%
# Create the shape file from these points and the spatial sampling masks,
#  which are = 1 at our fossil sites, and 0 everywhere else.
# These sampling masks will be updated later on to contain the sampling proportion at each site,
# not just a binary mask.
for interval in info_per_pcoord['interval'].unique():
	tmp_df = info_per_pcoord[info_per_pcoord.interval == interval]
	# the mask files for defining our spatial sampling
	mask_shp = os.path.join(data_directory, "paleo_maps",
							"pointsmask_{}.shp".format(interval.replace(" ", "_").lower()))
	mask_raster = os.path.join(data_directory, "paleo_maps",
							"paleomask_{}.tif".format(interval.replace(" ", "_").lower()))
	create_shapefile_from_points(tmp_df, mask_shp)
	# use our mask to create a binary raster map
	rasterize(mask_shp, mask_raster, pixel_size=0.01)

# %%
# Calculate the origins for each of the time points
mask_origins = {}
for interval in interval_list:
	mask_raster = os.path.join(data_directory, "paleo_maps",
							"paleomask_{}.tif".format(interval))
	paleo_mask = Map(mask_raster)
	_, _, _,_, x_res, y_res, ulx_mask, uly_mask = paleo_mask.get_dimensions()
	mask_origins[interval] = [uly_mask, ulx_mask, y_res, x_res]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-529aee9a2cd4> in <module>
#       5 							"paleomask_{}.tif".format(interval))
#       6         paleo_mask = Map(mask_raster)
# ----> 7         _, _, _,_, x_res, y_res, ulx_mask, uly_mask = paleo_mask.get_dimensions()
#       8         mask_origins[interval] = [uly_mask, ulx_mask, y_res, x_res]
#
# ~/Documents/PhD/Code/pycoalescence/pycoalescence/map.py in get_dimensions(self)
#     555         """
#     556         if self.x_size == 0 and self.y_size == 0:
# --> 557             return self.read_dimensions()
#     558         else:
#     559             return [
#
# ~/Documents/PhD/Code/pycoalescence/pycoalescence/map.py in read_dimensions(self)
#     518         :return: a list containing [0] x, [1] y, [2] upper left x, [3] upper left y, [4] x resolution, [5] y resolution
#     519         """
# --> 520         ulx, xres, xskew, uly, yskew, yres = self.get_geo_transform()
#     521         x, y = self.get_x_y()
#     522         return [x, y, self.x_offset, self.y_offset, xres, yres, ulx, uly]
#
# ~/Documents/PhD/Code/pycoalescence/pycoalescence/map.py in get_geo_transform(self)
#     542         :return: list containing the geotransform parameters
#     543         """
# --> 544         ds = self.get_dataset()
#     545         ulx, xres, xskew, uly, yskew, yres = ds.GetGeoTransform()
#     546         ds = None
#
# ~/Documents/PhD/Code/pycoalescence/pycoalescence/map.py in get_dataset(self, file, permissions)
#     264         if not self.map_exists(file):
#     265             raise IOError(
# --> 266                 "File {} does not exist or is not accessible." " Check read/write access.".format(self.file_name)
#     267             )
#     268         _, ext = os.path.splitext(self.file_name)
#
# OSError: File /run/media/sam/Media/Paleo/Data/paleo_maps/paleomask_permian.tif does not exist or is not accessible. Check read/write access.

# %%
# Generate the fragmented landscapes using random removal of points
# Then add our binary masks to the habitat map to ensure there is habitat at every cell we sample
pc_list = [0.1, 0.2, 0.5]
for interval in interval_list:
	for pc in pc_list:
		print(pc)
		input_map = os.path.join(data_directory, "paleo_maps", "{}.tif".format(interval))
		output_map = os.path.join(data_directory, "paleo_maps", "{}_fragmented_{}.tif".format(interval,
																							  pc))
		if not os.path.exists(output_map):
			randomly_clear_landscape(input_map, output_map, pc)
		mask_raster = os.path.join(data_directory, "paleo_maps",
								   "paleomask_{}.tif".format(interval))
		final_map = os.path.join(data_directory,
								 "paleo_maps", "{}_fragmented_{}_masked.tif".format(interval, pc))
		if not os.path.exists(final_map):
			add_masks(output_map, mask_raster, final_map)
# Out:
# 0.1
# 0.2
# 0.5
# 0.1
# 0.2
# 0.5
# 0.1
# 0.2
# 0.5

# %%
interval_max_ind = info_per_pcoord.groupby(["interval"])["individuals"].max()
interval_max_ind = interval_max_ind.rename({x : x.replace(" ", "_").lower() for x in interval_max_ind.keys()})

# %%
sum(info_per_pcoord[info_per_pcoord.interval == "Early Carboniferous"]["individuals"])
# Out:
# 32

# %%
# Create the fragment csv for defining fragments within the simulation
# This creates one fragment csv for each interval
# We now need to create our masks again, altering the values of the shapefile to match our fragment coordinates
# This seems a bit stupid, but because fragment coordinates can't be calculated until the mask file
# origin is known, this is the best way
if not os.path.exists(os.path.join(data_directory, "configs")):
	os.mkdir(os.path.join(data_directory, "configs"))
for interval in interval_list:
	columns = ['fragment', 'x_min', 'y_min', 'x_max', 'y_max', 'no_individuals']
	rows = [x for x in range(0, info_per_pcoord.shape[0], 1)]
	fragment_locations = pd.DataFrame(columns=columns, index=rows)
	fragment_map = Map(file=os.path.join(data_directory, "paleo_maps", "paleomask_{}.tif".format(interval)))
	fragment_map.open()
	for index, row in info_per_pcoord.iterrows():
		if row.interval.replace(" ", "_").lower() != interval:
			continue
		modifier = 0
		# # Weirdly one of the fragments is put above instead of below the geo-coord - change it here
		# if row.collection_ref == "174420":
		# 	modifier = -1
		fragment_locations.fragment[index] = row.collection_ref_2
		offsets = find_distance_lat_long(mask_origins[interval][0], mask_origins[interval][1], row.lat, row.long, 
										 res=mask_origins[interval][3])
		fragment_locations.x_min[index] = int(math.floor(offsets[1])) 
		fragment_locations.x_max[index] = int(math.floor(offsets[1] + 1))
		fragment_locations.y_min[index] = int(math.floor(offsets[0])) 
		fragment_locations.y_max[index] = int(math.floor(offsets[0] + 1)) + modifier
		fragment_locations.no_individuals[index] = row.individuals
		# Alter the fragment mask with updating the sampling values.  ***** add this back in if needed
		fragment_map.data[fragment_locations.y_min[index], fragment_locations.x_min[index]] = (1 + row.individuals)/interval_max_ind[interval]
	fragment_locations = fragment_locations[pd.notnull(fragment_locations['x_min'])]
	fragment_locations.to_csv(os.path.join(data_directory, "configs", "fragments_{}.csv".format(interval)),
							  index=False, header=False)
	fragment_map.write()

# %%
# Now double check that these all make sense
for interval in interval_list:
	df = pd.read_csv(os.path.join(data_directory, "configs", "fragments_{}.csv".format(interval)),
					 header=None)
	df.columns = ['fragment', 'x_min', 'y_min', 'x_max', 'y_max', 'no_individuals']
	mask_raster = Map(os.path.join(data_directory, "paleo_maps",
								   "paleomask_{}.tif".format(interval.replace(" ", "_").lower())))
	mask_value = mask_raster.get_cached_subset(0, 0, 1, 1)
	for index, row in df.iterrows():
		# print(row.fragment)
		mask_value = mask_raster.get_cached_subset(row.x_min, row.y_min, 1, 1)
		if not math.isclose(mask_value[0][0], row.no_individuals/interval_max_ind[interval], rel_tol=1e-2):
			print("Mask value not correct: {} != {}"
							 " for location {}, {} - fragment {}".format(mask_value[0][0],
																		 row.no_individuals/interval_max_ind[interval],
																		 row.x_min,
																		 row.y_min,
																		 row.fragment))
print("All maps verified")
# Out:
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 607, 3545 - fragment 11152
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 5805, 2695 - fragment 121601
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2179, 3689 - fragment 126543
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2203, 3616 - fragment 127110
# Mask value not correct: 0.23728813230991364 != 0.24324324324324326 for location 711, 3245 - fragment 12976-177014-177015
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 607, 3548 - fragment 13044
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 745, 3253 - fragment 13046
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 676, 3561 - fragment 13048
# Mask value not correct: 0.22033898532390594 != 0.10810810810810811 for location 613, 3551 - fragment 13080
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 640, 3643 - fragment 137131
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 9742, 8860 - fragment 156530
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 900, 3311 - fragment 163064
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 4882, 2430 - fragment 174685
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 610, 3567 - fragment 176438
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 633, 3554 - fragment 176442
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 591, 3577 - fragment 176495
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 647, 3591 - fragment 176499
# Mask value not correct: 0.0 != 0.08108108108108109 for location 713, 3243 - fragment 177017
# Mask value not correct: 0.08474576473236084 != 0.13513513513513514 for location 730, 3269 - fragment 177019
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 836, 3411 - fragment 177062
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2191, 3649 - fragment 177138
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 1053, 3249 - fragment 177144
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 5965, 2661 - fragment 177359
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 1082, 3154 - fragment 178666
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 583, 3536 - fragment 178669
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2185, 3650 - fragment 178674
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2179, 3643 - fragment 178675
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2169, 3633 - fragment 178676
# Mask value not correct: 0.16949152946472168 != 0.21621621621621623 for location 618, 3361 - fragment 178738
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 548, 3491 - fragment 178739
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 1034, 3196 - fragment 179595
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 226, 2979 - fragment 179932
# Mask value not correct: 0.35593220591545105 != 0.5675675675675675 for location 227, 2983 - fragment 180106-180383-180384
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 224, 2969 - fragment 180107
# Mask value not correct: 0.08474576473236084 != 0.05405405405405406 for location 224, 2982 - fragment 180382
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 191, 3015 - fragment 180465
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 7433, 4 - fragment 180643
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 6269, 2307 - fragment 180649
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 5798, 2748 - fragment 180764
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 5803, 2743 - fragment 180795
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2521, 6199 - fragment 180809
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 2516, 6225 - fragment 180810
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 6328, 2291 - fragment 180863
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 356, 2751 - fragment 180939
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 583, 3537 - fragment 180945
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 2209, 3617 - fragment 180946-180947
# Mask value not correct: 0.18644067645072937 != 0.08108108108108109 for location 201, 3009 - fragment 180974
# Mask value not correct: 0.08474576473236084 != 0.13513513513513514 for location 630, 3550 - fragment 180978
# Mask value not correct: 0.050847455859184265 != 0.05405405405405406 for location 1055, 3251 - fragment 180979
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 5490, 3164 - fragment 180981
# Mask value not correct: 0.16949152946472168 != 0.13513513513513514 for location 891, 3268 - fragment 180990
# Mask value not correct: 0.1355932205915451 != 0.16216216216216217 for location 735, 3466 - fragment 180991
# Mask value not correct: 0.06779661029577255 != 0.02702702702702703 for location 590, 3435 - fragment 180992
# Mask value not correct: 0.050847455859184265 != 0.02702702702702703 for location 5, 3201 - fragment 181037
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 199, 3011 - fragment 181076
# Mask value not correct: 0.10169491171836853 != 0.08108108108108109 for location 83, 3257 - fragment 181077
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 11158, 1085 - fragment 181085
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 965, 3137 - fragment 181086
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 969, 3135 - fragment 181087
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 10828, 1485 - fragment 181134
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 5994, 2755 - fragment 181176
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 633, 3592 - fragment 22635
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 741, 3254 - fragment 22670-22671
# Mask value not correct: 0.10169491171836853 != 0.02702702702702703 for location 656, 3518 - fragment 22714
# Mask value not correct: 0.16949152946472168 != 0.16216216216216217 for location 715, 3244 - fragment 27704
# Mask value not correct: 0.11864406615495682 != 0.05405405405405406 for location 191, 3009 - fragment 28067
# Mask value not correct: 0.0 != 0.10810810810810811 for location 608, 3595 - fragment 28120-28123-28124
# Mask value not correct: 0.11864406615495682 != 0.02702702702702703 for location 628, 3563 - fragment 28141
# Mask value not correct: 0.0 != 0.32432432432432434 for location 634, 3542 - fragment 28142
# Mask value not correct: 0.08474576473236084 != 0.05405405405405406 for location 630, 3530 - fragment 28149
# Mask value not correct: 0.16949152946472168 != 0.08108108108108109 for location 607, 3550 - fragment 28150
# Mask value not correct: 0.0 != 0.05405405405405406 for location 607, 3533 - fragment 28242
# Mask value not correct: 0.3050847351551056 != 0.2702702702702703 for location 605, 3526 - fragment 28250-71671-119428
# Mask value not correct: 0.33898305892944336 != 0.16216216216216217 for location 746, 3260 - fragment 28251-28261-28266
# Mask value not correct: 0.7627118825912476 != 1.0 for location 741, 3256 - fragment 28256
# Mask value not correct: 0.3050847351551056 != 0.24324324324324326 for location 739, 3256 - fragment 28264
# Mask value not correct: 0.5423728823661804 != 0.4864864864864865 for location 734, 3260 - fragment 28267
# Mask value not correct: 0.20338982343673706 != 0.10810810810810811 for location 732, 3256 - fragment 28270
# Mask value not correct: 0.20338982343673706 != 0.21621621621621623 for location 753, 3239 - fragment 28275
# Mask value not correct: 0.10169491171836853 != 0.08108108108108109 for location 626, 3566 - fragment 28324
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 808, 3518 - fragment 28394
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 730, 3268 - fragment 36571
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 3567, 3313 - fragment 48897
# Mask value not correct: 0.1525423675775528 != 0.24324324324324326 for location 5964, 2660 - fragment 52522
# Mask value not correct: 0.08474576473236084 != 0.13513513513513514 for location 6332, 2342 - fragment 58139
# Mask value not correct: 0.0 != 0.35135135135135137 for location 619, 3373 - fragment 67735
# Mask value not correct: 1.0 != 0.918918918918919 for location 745, 3401 - fragment 67862
# Mask value not correct: 0.2542372941970825 != 0.2972972972972973 for location 793, 3238 - fragment 67945
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 637, 3347 - fragment 68171
# Mask value not correct: 0.23728813230991364 != 0.2972972972972973 for location 225, 2985 - fragment 77412
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 758, 3099 - fragment 78559
# Mask value not correct: 0.3050847351551056 != 0.4864864864864865 for location 628, 3560 - fragment 79162-180957
# Mask value not correct: 0.22033898532390594 != 0.24324324324324326 for location 851, 3399 - fragment 79402
# Mask value not correct: 0.16949152946472168 != 0.21621621621621623 for location 893, 3306 - fragment 79408-84941-85567
# Mask value not correct: 0.10169491171836853 != 0.13513513513513514 for location 944, 3212 - fragment 79531
# Mask value not correct: 0.16949152946472168 != 0.24324324324324326 for location 753, 3103 - fragment 79600
# Mask value not correct: 0.22033898532390594 != 0.2972972972972973 for location 613, 3433 - fragment 79601-85361-85362-177006-177018
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 967, 3135 - fragment 79602
# Mask value not correct: 0.06779661029577255 != 0.10810810810810811 for location 790, 3074 - fragment 79694
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 665, 3442 - fragment 79813
# Mask value not correct: 0.1525423675775528 != 0.16216216216216217 for location 914, 3273 - fragment 79815
# Mask value not correct: 0.11864406615495682 != 0.08108108108108109 for location 60, 2745 - fragment 80110
# Mask value not correct: 0.2542372941970825 != 0.2702702702702703 for location 5805, 2692 - fragment 80112
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 253, 2984 - fragment 80130
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 610, 3426 - fragment 80574
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 5594, 3090 - fragment 80576
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 967, 3153 - fragment 80578
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 752, 3107 - fragment 80668
# Mask value not correct: 0.06779661029577255 != 0.10810810810810811 for location 757, 3099 - fragment 80669
# Mask value not correct: 0.08474576473236084 != 0.13513513513513514 for location 753, 3100 - fragment 80689
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 635, 3463 - fragment 80690
# Mask value not correct: 0.11864406615495682 != 0.05405405405405406 for location 738, 3374 - fragment 80691
# Mask value not correct: 0.050847455859184265 != 0.02702702702702703 for location 743, 3112 - fragment 80692
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 642, 3570 - fragment 80723
# Mask value not correct: 0.06779661029577255 != 0.10810810810810811 for location 744, 3114 - fragment 80729
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 930, 3325 - fragment 80732
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 607, 3542 - fragment 80741
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 226, 2985 - fragment 80770-180944
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 5489, 3161 - fragment 80777
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 2152, 3685 - fragment 80877
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 644, 3567 - fragment 84715
# Mask value not correct: 0.18644067645072937 != 0.2702702702702703 for location 611, 3547 - fragment 84716
# Mask value not correct: 0.08474576473236084 != 0.10810810810810811 for location 7162, 70 - fragment 84719
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 604, 3552 - fragment 85112
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 730, 3250 - fragment 85125
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 752, 3103 - fragment 85280
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 751, 3104 - fragment 85281
# Mask value not correct: 0.16949152946472168 != 0.08108108108108109 for location 604, 3524 - fragment 85299
# Mask value not correct: 0.08474576473236084 != 0.05405405405405406 for location 604, 3520 - fragment 85301
# Mask value not correct: 0.050847455859184265 != 0.08108108108108109 for location 611, 3528 - fragment 85341
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 733, 3253 - fragment 85342
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 248, 2764 - fragment 85475
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 247, 2765 - fragment 85478
# Mask value not correct: 0.08474576473236084 != 0.02702702702702703 for location 248, 2766 - fragment 85479
# Mask value not correct: 0.10169491171836853 != 0.16216216216216217 for location 711, 3249 - fragment 85550-177003-177005
# Mask value not correct: 0.10169491171836853 != 0.05405405405405406 for location 711, 3248 - fragment 85551
# Mask value not correct: 0.06779661029577255 != 0.08108108108108109 for location 710, 3249 - fragment 85552
# Mask value not correct: 0.0 != 0.1891891891891892 for location 717, 3243 - fragment 85555-177000-177002
# Mask value not correct: 0.033898305147886276 != 0.05405405405405406 for location 726, 3250 - fragment 85556-91038
# Mask value not correct: 0.1355932205915451 != 0.1891891891891892 for location 669, 3500 - fragment 85733
# Mask value not correct: 0.033898305147886276 != 0.02702702702702703 for location 632, 3510 - fragment 85950
# Mask value not correct: 0.10169491171836853 != 0.08108108108108109 for location 892, 3257 - fragment 87054
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 942, 3203 - fragment 87091
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 943, 3214 - fragment 87092
# Mask value not correct: 0.08474576473236084 != 0.02702702702702703 for location 724, 3243 - fragment 90452
# Mask value not correct: 0.016949152573943138 != 0.02702702702702703 for location 2144, 3683 - fragment 94802
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4371, 2334 - fragment 106270
# Mask value not correct: 0.30000001192092896 != 0.6 for location 5243, 1184 - fragment 132778-175821
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4797, 1961 - fragment 140937
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4338, 2336 - fragment 173986
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4779, 1968 - fragment 174063
# Mask value not correct: 0.30000001192092896 != 0.6 for location 4771, 1968 - fragment 174420
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4799, 1971 - fragment 175811
# Mask value not correct: 0.20000000298023224 != 0.4 for location 4800, 1970 - fragment 175812
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4372, 2391 - fragment 175813
# Mask value not correct: 0.10000000149011612 != 0.2 for location 20856, 1379 - fragment 176119
# Mask value not correct: 0.10000000149011612 != 0.2 for location 5, 4 - fragment 176121
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4736, 1969 - fragment 176673
# Mask value not correct: 0.20000000298023224 != 0.4 for location 4453, 2418 - fragment 183472
# Mask value not correct: 0.30000001192092896 != 0.6 for location 4463, 2413 - fragment 183473
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4486, 2402 - fragment 183474
# Mask value not correct: 0.5 != 0.6 for location 974, 1533 - fragment 68318
# Mask value not correct: 0.10000000149011612 != 0.2 for location 4879, 1859 - fragment 84940
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6685, 297 - fragment 109702
# Mask value not correct: 0.2777777910232544 != 0.23529411764705882 for location 1745, 923 - fragment 11165
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1788, 934 - fragment 113555
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 337, 971 - fragment 117869
# Mask value not correct: 0.0833333358168602 != 0.058823529411764705 for location 1974, 2854 - fragment 124949
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3261, 1103 - fragment 125142
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 6757, 685 - fragment 125662
# Mask value not correct: 0.1944444477558136 != 0.11764705882352941 for location 3259, 1196 - fragment 126535
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1289, 501 - fragment 12943
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3262, 1104 - fragment 13049
# Mask value not correct: 0.1944444477558136 != 0.058823529411764705 for location 1205, 114 - fragment 13257
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5583, 742 - fragment 137311
# Mask value not correct: 0.1944444477558136 != 0.058823529411764705 for location 1893, 1001 - fragment 13947
# Mask value not correct: 0.1944444477558136 != 0.14705882352941177 for location 6956, 290 - fragment 154179
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6979, 280 - fragment 155305
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 5352, 716 - fragment 157227
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 6931, 80 - fragment 160735
# Mask value not correct: 0.1388888955116272 != 0.029411764705882353 for location 2263, 506 - fragment 162676
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6582, 586 - fragment 164623
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 2674, 1913 - fragment 165526
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 4587, 800 - fragment 171344
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6592, 890 - fragment 171350
# Mask value not correct: 0.0555555559694767 != 0.029411764705882353 for location 1774, 955 - fragment 173721
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1353, 350 - fragment 173814
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3289, 1129 - fragment 173987
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 4814, 1725 - fragment 174421
# Mask value not correct: 0.0555555559694767 != 0.029411764705882353 for location 5277, 1256 - fragment 175174
# Mask value not correct: 0.0833333358168602 != 0.058823529411764705 for location 3573, 2831 - fragment 175248
# Mask value not correct: 0.25 != 0.20588235294117646 for location 4961, 1388 - fragment 175806
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5866, 1373 - fragment 175907
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6742, 273 - fragment 175918
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1598, 1182 - fragment 175919
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5128, 1078 - fragment 175922
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5251, 1251 - fragment 175970
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 2957, 1547 - fragment 176015
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 4209, 1622 - fragment 176017
# Mask value not correct: 0.1111111119389534 != 0.08823529411764706 for location 6495, 752 - fragment 176090
# Mask value not correct: 0.1111111119389534 != 0.11764705882352941 for location 2884, 1617 - fragment 176092
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3264, 1070 - fragment 176110
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5044, 1600 - fragment 176241
# Mask value not correct: 0.0833333358168602 != 0.058823529411764705 for location 5300, 769 - fragment 176242
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 5307, 1320 - fragment 176254
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5084, 1648 - fragment 176262
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5083, 1648 - fragment 176264
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3335, 1092 - fragment 176408
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1754, 961 - fragment 176496
# Mask value not correct: 0.0833333358168602 != 0.058823529411764705 for location 6018, 643 - fragment 176500
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1239, 549 - fragment 176523
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 6902, 84 - fragment 176531
# Mask value not correct: 0.1111111119389534 != 0.11764705882352941 for location 7039, 8 - fragment 176535
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6844, 149 - fragment 176536
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6910, 56 - fragment 176537
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6806, 258 - fragment 176538
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 7066, 165 - fragment 176539
# Mask value not correct: 0.1111111119389534 != 0.08823529411764706 for location 6846, 154 - fragment 176543
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6598, 562 - fragment 176771
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 1033, 894 - fragment 176968
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3138, 1220 - fragment 177046
# Mask value not correct: 0.1388888955116272 != 0.11764705882352941 for location 3260, 1103 - fragment 177058
# Mask value not correct: 0.1666666716337204 != 0.11764705882352941 for location 5088, 1434 - fragment 177139
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6734, 275 - fragment 178271
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3156, 1250 - fragment 178677
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 2842, 1614 - fragment 178682
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 2917, 1578 - fragment 178696
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 2847, 1605 - fragment 178697
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 2900, 1570 - fragment 178698
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6761, 232 - fragment 178735
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 6752, 244 - fragment 178736
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 5303, 756 - fragment 178804
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3198, 1175 - fragment 178844
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5270, 1140 - fragment 178845
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1165, 2119 - fragment 178846
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3201, 1183 - fragment 179045
# Mask value not correct: 0.0833333358168602 != 0.058823529411764705 for location 7209, 18 - fragment 179047
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 5305, 761 - fragment 179053
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6757, 238 - fragment 179127
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3313, 1072 - fragment 179596
# Mask value not correct: 0.0833333358168602 != 0.029411764705882353 for location 2264, 506 - fragment 179619
# Mask value not correct: 0.2222222238779068 != 0.11764705882352941 for location 2263, 505 - fragment 179620
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6695, 329 - fragment 179644
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1243, 553 - fragment 179964
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6762, 239 - fragment 180284
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1754, 946 - fragment 180393
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6425, 767 - fragment 180632
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6602, 553 - fragment 180674
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6869, 172 - fragment 180675
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6876, 167 - fragment 180757
# Mask value not correct: 0.0833333358168602 != 0.029411764705882353 for location 7019, 329 - fragment 180761
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 6906, 84 - fragment 180765-180848-181128
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6908, 87 - fragment 180778
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6917, 68 - fragment 180779
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 7181, 4 - fragment 180780
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 6770, 270 - fragment 180783
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 6745, 259 - fragment 180796
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6773, 239 - fragment 180797
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6744, 259 - fragment 180798
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6908, 86 - fragment 180799
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6768, 221 - fragment 180800
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6598, 561 - fragment 180801
# Mask value not correct: 0.1666666716337204 != 0.17647058823529413 for location 6757, 240 - fragment 180802-180853-180860-180869
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6728, 294 - fragment 180803
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6750, 250 - fragment 180804-180862
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 6765, 253 - fragment 180805
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 6764, 300 - fragment 180806
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6777, 226 - fragment 180817
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6911, 90 - fragment 180847
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6757, 237 - fragment 180851
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6752, 249 - fragment 180854
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6753, 242 - fragment 180855
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6755, 241 - fragment 180857
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6747, 233 - fragment 180858
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6739, 267 - fragment 180859
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6767, 267 - fragment 180861
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6715, 284 - fragment 180864
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6743, 268 - fragment 180865
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 6745, 257 - fragment 180870
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6760, 257 - fragment 180872
# Mask value not correct: 0.0 != 0.029411764705882353 for location 3207, 1317 - fragment 180937
# Mask value not correct: 0.1111111119389534 != 0.08823529411764706 for location 1357, 510 - fragment 180938
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 7028, 63 - fragment 180950
# Mask value not correct: 0.2222222238779068 != 0.029411764705882353 for location 1212, 463 - fragment 180989
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6675, 520 - fragment 181051
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6902, 91 - fragment 181127
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6914, 97 - fragment 181129
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6902, 83 - fragment 181130
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1744, 951 - fragment 22667
# Mask value not correct: 0.25 != 0.11764705882352941 for location 4800, 1703 - fragment 22726
# Mask value not correct: 0.1388888955116272 != 0.11764705882352941 for location 10923, 6262 - fragment 27263
# Mask value not correct: 0.6666666865348816 != 0.5294117647058824 for location 3753, 2085 - fragment 28069-86946-175937
# Mask value not correct: 0.5277777910232544 != 0.5 for location 1320, 448 - fragment 34761
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 7333, 77 - fragment 51265
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 2091, 764 - fragment 68427
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 5879, 1392 - fragment 75090
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 1358, 509 - fragment 77786
# Mask value not correct: 0.1666666716337204 != 0.11764705882352941 for location 1717, 956 - fragment 79163-132661
# Mask value not correct: 0.3333333432674408 != 0.3235294117647059 for location 2448, 1263 - fragment 79598
# Mask value not correct: 0.2222222238779068 != 0.14705882352941177 for location 4386, 1571 - fragment 80111
# Mask value not correct: 0.3333333432674408 != 0.29411764705882354 for location 2631, 1106 - fragment 80714
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 6487, 717 - fragment 80716
# Mask value not correct: 0.0555555559694767 != 0.029411764705882353 for location 3289, 1019 - fragment 80720
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 7259, 17 - fragment 80773
# Mask value not correct: 0.0833333358168602 != 0.08823529411764706 for location 6133, 89 - fragment 80783
# Mask value not correct: 0.3333333432674408 != 0.29411764705882354 for location 2038, 984 - fragment 80784
# Mask value not correct: 0.0555555559694767 != 0.029411764705882353 for location 2621, 1083 - fragment 81114
# Mask value not correct: 0.1111111119389534 != 0.11764705882352941 for location 1862, 2298 - fragment 81525
# Mask value not correct: 0.1111111119389534 != 0.11764705882352941 for location 1840, 2276 - fragment 84135
# Mask value not correct: 0.75 != 0.7058823529411765 for location 6749, 699 - fragment 84835
# Mask value not correct: 0.02777777798473835 != 0.029411764705882353 for location 3329, 1062 - fragment 85178
# Mask value not correct: 0.1388888955116272 != 0.14705882352941177 for location 6761, 255 - fragment 85451
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 7088, 12 - fragment 85474
# Mask value not correct: 0.0555555559694767 != 0.058823529411764705 for location 7317, 87 - fragment 87877
# Mask value not correct: 0.1944444477558136 != 0.11764705882352941 for location 5, 1498 - fragment 92271
# All maps verified
