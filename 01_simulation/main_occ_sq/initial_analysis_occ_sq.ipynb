# %% [markdown]
# # Initial main simulation analysis
#
# - Performs the precursory analysis for the first set of main simulations

# %%
import os
from collections import OrderedDict
from random import sample
from tqdm import tqdm_notebook
import logging
import pandas as pd
from math import floor
import shutil
import pathlib
import sqlite3

# %%
# For dev use only - auto-reloading of modules
# %load_ext autoreload
# %aimport pycoalescence.coalescence_tree
from pycoalescence.coalescence_tree import check_sql_table_exist
from pycoalescence.helper import update_parameter_names
from pycoalescence import CoalescenceTree
from pycoalescence.sqlite_connection import check_sql_table_exist, SQLiteConnection
from compress_times import compress_times, double_backup, double_restore_backup, get_unique_times

# %autoreload 1

# %%
intervals = {'artinskian',
 'asselian',
 'bashkirian',
 'gzhelian',
 'kasimovian',
 'kungurian',
 'moscovian',
 'sakmarian'}

tetrapod_groups = {'amniote', 'amphibian'}

# %%
def percent_cover_detection(fine_map_file):
	"""
	Detects the percentage cover from the fine map path
	:param fine_map_file: path to check for
	:return: the simulation percentage cover
	"""
	for pc in [0.1, 0.2, 0.4, 0.8]:
		if "_{}_".format(pc) in fine_map_file:
			return pc
	raise ValueError("No percentage cover detected!")

# %%
def sim_type_detection(fine_map_file):
	"""
	Detects the simulation type from the fine map path (because I didn't save it anywhere sensible!
	:param fine_map_file: the path to check for
	:return the sim type
	"""
	for interval in intervals:
		for tet_group in tetrapod_groups:
			if interval in fine_map_file and tet_group in fine_map_file:
				return (interval, tet_group)
	raise ValueError("No type detected! Filename: {}.".format(fine_map_file))

# %%
def sim_scenario_detection(file):
    """
    Detects the scenario from the file name
    :param the file name to check
    :return the scenario
    """
    for scenario in ["fragmented", "clustered", "pristine"]:
        if scenario in file:
            return scenario
    raise ValueError("Scenario not detected")

# %%
# Set the import directories and variables - paths relative to the jupyter notebook directory
# fragmented="fragmented"
fragmented = "all"  # put back if want to analyse normal sims
local_dir = "/home/sam/Documents/PhD/PaleoSampling"
ext_dir = "/run/media/sam/Media/Paleo"
# local_dir = "/Users/samthompson/Documents/PhD/PaleoSampling/"
# ext_dir = "/Volumes/Seagate 3TB/Paleo/"
results_dir = os.path.join(ext_dir, "Results", "PaleoMainOcc2b")
dst_folder = os.path.join(local_dir, "Results", "PaleoMainOcc2")
dst_folder2 = os.path.join(
    local_dir, "Code", "MainSimulationR", "results", "PaleoMainOcc2"
)
data_dir = os.path.join(ext_dir, "Data")
speciation_rates = [
    0.000_000_01,
    0.000_000_001,
    0.000_000_002,
    0.000_000_004,
    0.000_000_006,
    0.000_000_008,
    0.000_000_05,
    0.000_000_1,
    0.000_001,
]
sim_int = 2
directory_descriptions = [
    ("Main{}".format(sim_int), "pristine"),
    ("Fragmented{}".format(sim_int), "fragmented"),
    ("Clustered{}".format(sim_int), "clustered"),
]

# %%
# Extract the files into a single directory
logging.getLogger().setLevel(20)
for directory, description in directory_descriptions:
    parent_dir = pathlib.Path(results_dir, directory)
    if parent_dir.exists():
        for folder in parent_dir.iterdir():
            if folder.is_dir():
                for file in folder.iterdir():
                    if file.is_file():
                        try:
                            c = CoalescenceTree(file)
                            seed = c.get_simulation_parameters()["seed"]
                            job_type = c.get_simulation_parameters()["job_type"]
                        except IOError as ioe:
                            if description == "main":
                                raise IOError(f"File {file.name} is not a completed simulation: {description}, {job_type}, {seed}")
                            else:
                                logging.info(f"Deleting {file.name}...")
                                file.unlink()
                                continue
                        except Exception as e:
                            logging.info("Skipping {}: {}...".format(file, e))
                            file.unlink()
                            continue
                        dest = pathlib.Path(results_dir, "{}_{}_{}.db".format(description, job_type, seed))
                        shutil.move(file, dest)
                    else:
                        logging.info("Skipping {}...".format(file))
            else:
                logging.info("Skipping {} - not a directory...".format(folder))
# Out:
# INFO:root:Deleting data_18_23.db...
# INFO:root:Deleting data_18_13.db...
# INFO:root:Deleting data_18_4.db...
# INFO:root:Deleting data_18_20.db...
# INFO:root:Deleting data_18_16.db...
# INFO:root:Deleting data_18_21.db...
# INFO:root:Deleting data_18_5.db...
# INFO:root:Deleting data_18_14.db...
# INFO:root:Deleting data_18_10.db...
# INFO:root:Deleting data_18_19.db...
# INFO:root:Deleting data_18_2.db...
# INFO:root:Deleting data_18_9.db...
# INFO:root:Deleting data_18_18.db...
# INFO:root:Deleting data_18_11.db...
# INFO:root:Deleting data_8_5.db...
# INFO:root:Deleting data_8_23.db...
# INFO:root:Deleting data_8_19.db...
# INFO:root:Deleting data_8_20.db...
# INFO:root:Deleting data_10_19.db...
# INFO:root:Deleting data_10_5.db...
# INFO:root:Deleting data_12_23.db...
# INFO:root:Deleting data_12_20.db...
# INFO:root:Deleting data_12_9.db...
# INFO:root:Deleting data_12_16.db...
# INFO:root:Deleting data_12_22.db...
# INFO:root:Deleting data_12_14.db...
# INFO:root:Deleting data_12_10.db...
# INFO:root:Deleting data_12_4.db...
# INFO:root:Deleting data_12_21.db...
# INFO:root:Deleting data_12_19.db...
# INFO:root:Deleting data_12_5.db...
# INFO:root:Deleting data_12_13.db...
# INFO:root:Deleting data_12_2.db...
# INFO:root:Deleting data_12_18.db...
# INFO:root:Deleting data_44_23.db...
# INFO:root:Deleting data_44_11.db...
# INFO:root:Deleting data_44_16.db...
# INFO:root:Deleting data_44_10.db...
# INFO:root:Deleting data_44_5.db...
# INFO:root:Deleting data_44_19.db...
# INFO:root:Deleting data_44_6.db...
# INFO:root:Deleting data_44_2.db...
# INFO:root:Deleting data_44_21.db...
# INFO:root:Deleting data_44_15.db...
# INFO:root:Deleting data_44_20.db...
# INFO:root:Deleting data_44_9.db...
# INFO:root:Deleting data_44_4.db...
# INFO:root:Deleting data_44_18.db...
# INFO:root:Deleting data_44_14.db...
# INFO:root:Deleting data_28_14.db...
# INFO:root:Deleting data_28_5.db...
# INFO:root:Deleting data_28_19.db...
# INFO:root:Deleting data_28_20.db...
# INFO:root:Deleting data_28_16.db...
# INFO:root:Deleting data_28_9.db...
# INFO:root:Deleting data_28_23.db...
# INFO:root:Deleting data_28_15.db...
# INFO:root:Deleting data_28_18.db...
# INFO:root:Deleting data_28_2.db...
# INFO:root:Deleting data_28_4.db...
# INFO:root:Deleting data_28_10.db...
# INFO:root:Deleting data_28_11.db...
# INFO:root:Deleting data_28_6.db...
# INFO:root:Deleting data_28_21.db...
# INFO:root:Deleting data_9_19.db...
# INFO:root:Deleting data_9_4.db...
# INFO:root:Deleting data_9_5.db...
# INFO:root:Deleting data_9_20.db...
# INFO:root:Deleting data_20_19.db...
# INFO:root:Deleting data_25_20.db...
# INFO:root:Deleting data_25_19.db...
# INFO:root:Deleting data_25_4.db...
# INFO:root:Deleting data_35_18.db...
# INFO:root:Deleting data_35_10.db...
# INFO:root:Deleting data_35_24.db...
# INFO:root:Deleting data_35_11.db...
# INFO:root:Deleting data_35_20.db...
# INFO:root:Deleting data_35_4.db...
# INFO:root:Deleting data_35_15.db...
# INFO:root:Deleting data_35_14.db...
# INFO:root:Deleting data_35_5.db...
# INFO:root:Deleting data_35_23.db...
# INFO:root:Deleting data_35_16.db...
# INFO:root:Deleting data_35_13.db...
# INFO:root:Deleting data_35_21.db...
# INFO:root:Deleting data_35_19.db...
# INFO:root:Deleting data_35_8.db...
# INFO:root:Deleting data_35_6.db...
# INFO:root:Deleting data_35_9.db...
# INFO:root:Deleting data_35_2.db...
# INFO:root:Deleting data_32_4.db...
# INFO:root:Deleting data_32_20.db...
# INFO:root:Deleting data_32_19.db...
# INFO:root:Deleting data_32_5.db...
# INFO:root:Deleting data_32_18.db...
# INFO:root:Deleting data_32_21.db...
# INFO:root:Deleting data_32_15.db...
# INFO:root:Deleting data_32_2.db...
# INFO:root:Deleting data_16_4.db...
# INFO:root:Deleting data_16_16.db...
# INFO:root:Deleting data_16_18.db...
# INFO:root:Deleting data_16_15.db...
# INFO:root:Deleting data_16_23.db...
# INFO:root:Deleting data_16_14.db...
# INFO:root:Deleting data_16_21.db...
# INFO:root:Deleting data_16_5.db...
# INFO:root:Deleting data_16_19.db...
# INFO:root:Deleting data_16_20.db...
# INFO:root:Deleting data_16_2.db...
# INFO:root:Deleting data_13_6.db...
# INFO:root:Deleting data_13_11.db...
# INFO:root:Deleting data_13_19.db...
# INFO:root:Deleting data_13_10.db...
# INFO:root:Deleting data_13_3.db...
# INFO:root:Deleting data_13_16.db...
# INFO:root:Deleting data_13_14.db...
# INFO:root:Deleting data_13_5.db...
# INFO:root:Deleting data_13_15.db...
# INFO:root:Deleting data_13_2.db...
# INFO:root:Deleting data_13_18.db...
# INFO:root:Deleting data_13_20.db...
# INFO:root:Deleting data_13_17.db...
# INFO:root:Deleting data_13_4.db...
# INFO:root:Deleting data_13_9.db...
# INFO:root:Deleting data_13_23.db...
# INFO:root:Deleting data_48_2.db...
# INFO:root:Deleting data_48_22.db...
# INFO:root:Deleting data_48_11.db...
# INFO:root:Deleting data_48_4.db...
# INFO:root:Deleting data_48_15.db...
# INFO:root:Deleting data_48_14.db...
# INFO:root:Deleting data_48_21.db...
# INFO:root:Deleting data_48_18.db...
# INFO:root:Deleting data_48_5.db...
# INFO:root:Deleting data_48_20.db...
# INFO:root:Deleting data_48_19.db...
# INFO:root:Skipping /run/media/sam/Media/Paleo/Results/PaleoMainOcc2b/Fragmented2/40/data_40_15.db: Error checking simulation was complete: file is not a database...
# INFO:root:Deleting data_40_19.db...
# INFO:root:Deleting data_45_23.db...
# INFO:root:Deleting data_45_5.db...
# INFO:root:Deleting data_45_8.db...
# INFO:root:Deleting data_45_15.db...
# INFO:root:Deleting data_45_18.db...
# INFO:root:Deleting data_45_19.db...
# INFO:root:Deleting data_45_12.db...
# INFO:root:Deleting data_45_14.db...
# INFO:root:Deleting data_45_24.db...
# INFO:root:Deleting data_45_9.db...
# INFO:root:Deleting data_45_2.db...
# INFO:root:Deleting data_45_16.db...
# INFO:root:Deleting data_45_20.db...
# INFO:root:Deleting data_45_10.db...
# INFO:root:Deleting data_45_3.db...
# INFO:root:Deleting data_45_22.db...
# INFO:root:Deleting data_45_21.db...
# INFO:root:Deleting data_45_11.db...
# INFO:root:Deleting data_45_4.db...
# INFO:root:Deleting data_29_23.db...
# INFO:root:Deleting data_29_20.db...
# INFO:root:Deleting data_29_14.db...
# INFO:root:Deleting data_29_15.db...
# INFO:root:Deleting data_29_12.db...
# INFO:root:Deleting data_29_19.db...
# INFO:root:Deleting data_29_18.db...
# INFO:root:Deleting data_29_16.db...
# INFO:root:Deleting data_29_4.db...
# INFO:root:Deleting data_29_21.db...
# INFO:root:Deleting data_29_7.db...
# INFO:root:Deleting data_29_10.db...
# INFO:root:Deleting data_29_2.db...
# INFO:root:Deleting data_29_5.db...
# INFO:root:Deleting data_29_11.db...
# INFO:root:Deleting data_29_6.db...
# INFO:root:Skipping /run/media/sam/Media/Paleo/Results/PaleoMainOcc2b/Fragmented2/4/data_4_19.db: Error checking simulation was complete: file is not a database...
# INFO:root:Deleting data_2_2.db...
# INFO:root:Deleting data_2_5.db...
# INFO:root:Deleting data_2_16.db...
# INFO:root:Deleting data_2_23.db...
# INFO:root:Deleting data_2_9.db...
# INFO:root:Deleting data_2_14.db...
# INFO:root:Deleting data_2_18.db...
# INFO:root:Deleting data_2_21.db...
# INFO:root:Deleting data_2_20.db...
# INFO:root:Deleting data_2_11.db...
# INFO:root:Deleting data_2_19.db...
# INFO:root:Deleting data_2_4.db...
# INFO:root:Deleting data_5_5.db...
# INFO:root:Deleting data_5_4.db...
# INFO:root:Deleting data_5_19.db...
# INFO:root:Deleting data_5_20.db...
# INFO:root:Deleting data_5_21.db...
# INFO:root:Deleting data_5_23.db...
# INFO:root:Deleting data_33_5.db...
# INFO:root:Deleting data_33_4.db...
# INFO:root:Deleting data_33_15.db...
# INFO:root:Deleting data_33_11.db...
# INFO:root:Deleting data_33_16.db...
# INFO:root:Deleting data_33_3.db...
# INFO:root:Deleting data_33_24.db...
# INFO:root:Deleting data_33_21.db...
# INFO:root:Deleting data_33_22.db...
# INFO:root:Deleting data_33_19.db...
# INFO:root:Deleting data_33_13.db...
# INFO:root:Deleting data_33_18.db...
# INFO:root:Deleting data_33_10.db...
# INFO:root:Deleting data_33_14.db...
# INFO:root:Deleting data_33_23.db...
# INFO:root:Deleting data_33_2.db...
# INFO:root:Deleting data_33_20.db...
# INFO:root:Deleting data_33_9.db...
# INFO:root:Deleting data_17_6.db...
# INFO:root:Deleting data_17_5.db...
# INFO:root:Deleting data_17_10.db...
# INFO:root:Deleting data_17_24.db...
# INFO:root:Deleting data_17_22.db...
# INFO:root:Deleting data_17_11.db...
# INFO:root:Deleting data_17_21.db...
# INFO:root:Deleting data_17_4.db...
# INFO:root:Deleting data_17_15.db...
# INFO:root:Deleting data_17_14.db...
# INFO:root:Deleting data_17_9.db...
# INFO:root:Deleting data_17_23.db...
# INFO:root:Deleting data_17_20.db...
# INFO:root:Deleting data_17_18.db...
# INFO:root:Deleting data_17_19.db...
# INFO:root:Deleting data_17_16.db...
# INFO:root:Deleting data_17_13.db...
# INFO:root:Deleting data_19_23.db...
# INFO:root:Deleting data_19_3.db...
# INFO:root:Deleting data_19_21.db...
# INFO:root:Deleting data_19_9.db...
# INFO:root:Deleting data_19_4.db...
# INFO:root:Deleting data_19_19.db...
# INFO:root:Deleting data_19_20.db...
# INFO:root:Deleting data_19_13.db...
# INFO:root:Deleting data_19_11.db...
# INFO:root:Deleting data_19_6.db...
# INFO:root:Deleting data_19_10.db...
# INFO:root:Deleting data_19_5.db...
# INFO:root:Deleting data_19_16.db...
# INFO:root:Deleting data_19_14.db...
# INFO:root:Deleting data_19_18.db...
# INFO:root:Deleting data_49_22.db...
# INFO:root:Deleting data_49_5.db...
# INFO:root:Deleting data_49_15.db...
# INFO:root:Deleting data_49_23.db...
# INFO:root:Deleting data_49_10.db...
# INFO:root:Deleting data_49_9.db...
# INFO:root:Deleting data_49_13.db...
# INFO:root:Deleting data_49_18.db...
# INFO:root:Deleting data_49_20.db...
# INFO:root:Deleting data_49_24.db...
# INFO:root:Deleting data_49_4.db...
# INFO:root:Deleting data_49_6.db...
# INFO:root:Deleting data_49_11.db...
# INFO:root:Deleting data_49_3.db...
# INFO:root:Deleting data_49_21.db...
# INFO:root:Deleting data_49_14.db...
# INFO:root:Deleting data_49_16.db...
# INFO:root:Deleting data_49_19.db...
# INFO:root:Deleting data_11_19.db...
# INFO:root:Deleting data_41_20.db...
# INFO:root:Deleting data_41_19.db...
# INFO:root:Deleting data_3_2.db...
# INFO:root:Deleting data_3_9.db...
# INFO:root:Deleting data_3_16.db...
# INFO:root:Deleting data_3_10.db...
# INFO:root:Deleting data_3_23.db...
# INFO:root:Deleting data_3_13.db...
# INFO:root:Deleting data_3_4.db...
# INFO:root:Deleting data_3_5.db...
# INFO:root:Deleting data_3_20.db...
# INFO:root:Deleting data_3_15.db...
# INFO:root:Deleting data_3_14.db...
# INFO:root:Deleting data_3_24.db...
# INFO:root:Deleting data_3_19.db...
# INFO:root:Deleting data_3_6.db...
# INFO:root:Deleting data_3_18.db...
# INFO:root:Deleting data_24_5.db...
# INFO:root:Deleting data_24_19.db...
# INFO:root:Deleting data_24_23.db...
# INFO:root:Deleting data_21_19.db...
# INFO:root:Deleting data_21_20.db...
# INFO:root:Deleting data_21_4.db...
# INFO:root:Deleting data_21_5.db...
# INFO:root:Deleting data_21_23.db...
# INFO:root:Deleting data_21_21.db...
# INFO:root:Deleting data_37_19.db...
# INFO:root:Deleting data_37_14.db...
# INFO:root:Deleting data_37_23.db...
# INFO:root:Deleting data_37_21.db...
# INFO:root:Deleting data_37_4.db...
# INFO:root:Deleting data_37_20.db...
# INFO:root:Deleting data_37_5.db...
# INFO:root:Deleting data_37_11.db...
# INFO:root:Deleting data_34_6.db...
# INFO:root:Deleting data_34_13.db...
# INFO:root:Deleting data_34_4.db...
# INFO:root:Deleting data_34_2.db...
# INFO:root:Deleting data_34_14.db...
# INFO:root:Deleting data_34_20.db...
# INFO:root:Deleting data_34_15.db...
# INFO:root:Deleting data_34_11.db...
# INFO:root:Deleting data_34_23.db...
# INFO:root:Deleting data_34_9.db...
# INFO:root:Deleting data_34_19.db...
# INFO:root:Deleting data_34_16.db...
# INFO:root:Deleting data_34_21.db...
# INFO:root:Deleting data_34_18.db...
# INFO:root:Deleting data_34_5.db...

# %%
for directory, _ in directory_descriptions:
    parent_dir = pathlib.Path(results_dir, directory)
    if parent_dir.exists():
        for folder in parent_dir.iterdir():
            if folder.is_dir():
                try:
                    folder.rmdir()
                except IOError as ioe:
                    logging.info("Cannot remove {}: {}".format(folder, ioe))
                    continue
        try:
            parent_dir.rmdir()
        except IOError as ioe:
            logging.info("Cannot remove {}: {}.".format(parent_dir, ioe))

# %%
# Delete all simulations which haven't completed yet.
for file in os.listdir(results_dir):
	if ".db" in file:
		try:
			t = CoalescenceTree(os.path.join(results_dir, file))
		except IOError:
			print("Removing incomplete simulation {}.".format(file))
			os.remove(os.path.join(results_dir, file))

# %%
max_density = None
# max_density = OrderedDict([(('artinskian', 'amniote'), 225),
#                            (('artinskian', 'amphibian'), 225),
#                            (('asselian', 'amniote'), 36),
#                            (('asselian', 'amphibian'), 36),
#                            (('bashkirian', 'amniote'), 1),
#                            (('bashkirian', 'amphibian'), 529),
#                            (('gzhelian', 'amniote'), 49),
#                            (('gzhelian', 'amphibian'), 49),
#                            (('kasimovian', 'amniote'), 49),
#                            (('kasimovian', 'amphibian'), 16),
#                            (('kungurian', 'amniote'), 225),
#                            (('kungurian', 'amphibian'), 289),
#                            (('moscovian', 'amniote'), 16),
#                            (('moscovian', 'amphibian'), 441),
#                            (('sakmarian', 'amniote'), 36),
#                            (('sakmarian', 'amphibian'), 225)])

# %%
# Calculate the biodiversity metrics -  can take a bit of time
for file in tqdm_notebook(os.listdir(results_dir), desc="Files"):
    file_path = os.path.join(results_dir, file)
    f, ext = os.path.splitext(file_path)
    if ".db" == ext:
#         print(file)
        t = CoalescenceTree(file_path)
        double_restore_backup(t)
        if check_sql_table_exist(t.database, "SPECIES_LIST_ORIGINAL"):
            t.revert_downsample()
        
        t.wipe_data()
        try:
            t._restore_backup_species_list()
        except sqlite3.OperationalError:
            pass
        sim_params = t.get_simulation_parameters()
        (interval, tet_group) = sim_type_detection(sim_params["sample_file"])
        deme = sim_params["deme"]
        sample_size = sim_params["sample_size"]
        fragment_csv = os.path.join(data_dir, "configs",
                                    "fragments_occ_{}_{}.csv".format(interval, tet_group))
        compress_times(t)
        double_backup(t)
        t.downsample_at_locations(fragment_csv=fragment_csv, ignore_errors=True)
#         downsample_rate = max_density[(interval, tet_group)] /( deme * sample_size)
#         try:
#             t.downsample(downsample_rate)
#         except ValueError:
#             logging.warning("Skipping file {} for {}, {} because downsample rate ({}) > 1.0".format(file, interval, tet_group, downsample_rate))
        t.set_speciation_parameters(record_spatial=True,
                                record_fragments=fragment_csv,
                                speciation_rates=speciation_rates)
        t.clear_calculations()
        t.apply()
        t.import_comparison_data(os.path.join(data_dir, "databases", "{}_{}_occ_sq.db".format(interval, tet_group)))
#         t.adjust_data()
        t._clear_goodness_of_fit()
        t.calculate_fragment_richness()
        # t.calculate_alpha_diversity()
        t.calculate_beta_diversity()
        # break
        t.calculate_goodness_of_fit()
# Out:
# HBox(children=(IntProgress(value=0, description='Files', max=1170, style=ProgressStyle(description_width='init…
# 	Lineage at 112 has not speciated and parent is 0. Integer overflow possible. Correcting by setting gens_alive to min value necessary for speciation.
#
# 	Lineage at 17 has not speciated and parent is 0. Integer overflow possible. Correcting by setting gens_alive to min value necessary for speciation.
#
# 	Lineage at 103 has not speciated and parent is 0. Integer overflow possible. Correcting by setting gens_alive to min value necessary for speciation.
#
# 	Lineage at 114 has not speciated and parent is 0. Integer overflow possible. Correcting by setting gens_alive to min value necessary for speciation.
#
# 	Lineage at 17 has not speciated and parent is 0. Integer overflow possible. Correcting by setting gens_alive to min value necessary for speciation.
#
# 	Lineage at 101 has not speciated and parent is 0. Integer overflow possible. Correcting by setting gens_alive to min value necessary for speciation.

# %%
# Sample from the simulations
tmp = []
distance_sim_tmp = []
fragment_abundances = []
for file in tqdm_notebook(os.listdir(results_dir), desc="Files"):
    file_path = os.path.join(results_dir, file)
    _, ext = os.path.splitext(file_path)
    if ".db" == ext:
        # print(file)
        t = CoalescenceTree(file_path)
        if check_sql_table_exist(t.database, "SPECIES_DISTANCE_SIMILARITY"):
            t.cursor.execute("DROP TABLE IF EXISTS SPECIES_DISTANCE_SIMILARITY")
        t.calculate_species_distance_similarity()
        if not check_sql_table_exist(t.database, "BIODIVERSITY_METRICS"):
            logging.warning("Skipping {} as BIODIVERSITY_METRICS table doesn't exist.".format(file))
            continue
        for sr in speciation_rates:
                ref = t.get_community_reference(speciation_rate=sr, time=0.0, fragments=True)
                spec_r = t.cursor.execute("SELECT actual FROM BIODIVERSITY_METRICS WHERE"
                                     " community_reference==? AND fragment=='whole' AND "
                                     "metric=='fragment_richness'", 
                                     (ref,)).fetchall()[0][0]
                b = t.cursor.execute("SELECT actual FROM BIODIVERSITY_METRICS WHERE"
                                     " community_reference==? AND fragment=='whole' AND "
                                     "metric=='beta_diversity'", 
                                     (ref,)).fetchall()[0][0]
                a = t.cursor.execute("SELECT actual FROM BIODIVERSITY_METRICS WHERE"
                                     " community_reference==? AND fragment=='whole' AND "
                                     "metric=='alpha_diversity'", 
                                     (ref,)).fetchall()[0][0]
                sim_params = t.get_simulation_parameters()
                species_richness = t.get_species_richness(ref)
                beta = t.get_beta_diversity(ref)
                alpha = t.get_alpha_diversity(ref)
                goodness_fit = t.get_goodness_of_fit(reference=ref)
                total_ind = t.get_number_individuals(community_reference=ref)
                (interval, tet_group) = sim_type_detection(sim_params["sample_file"])
                scenario = sim_scenario_detection(file)
                if scenario == "fragmented":
                    pc = percent_cover_detection(sim_params["fine_map_file"])
                else:
                    pc = 1.0
                tmp.append({"interval": interval, "tetrapod_group" : tet_group,
                            "sigma" : sim_params["sigma"], "speciation_rate" : sr,
                            "deme" : sim_params["deme"], "richness" : species_richness,
                            "beta_diversity" : beta, "alpha_diversity" : alpha,
                            "gof" : goodness_fit, "actual_richness" : spec_r, "actual_beta" : b,
                            "actual_alpha" : a, "percent_cover": pc, "simulated_individuals" : total_ind, "scenario" : scenario})
                # try:
                distance_sim = t.get_species_distance_similarity(ref)
                for distance, no_ind in distance_sim:
                    distance_sim_tmp.append({"interval": interval, "tetrapod_group" : tet_group,
                                             "sigma" : sim_params["sigma"], "speciation_rate" : sr,
                            "deme" : sim_params["deme"], "richness" : species_richness,
                            "beta_diversity" : beta, "alpha_diversity" : alpha,
                            "gof" : goodness_fit, "actual_richness" : spec_r, "actual_beta" : b,
                            "actual_alpha" : a, "distance" : distance, "no_individuals" : no_ind,"percent_cover": pc, "scenario" : scenario})
                for fragment in t.get_fragment_list(ref):
                    r = t.get_fragment_richness(fragment, ref)
                    fragment_abundances.append({"interval": interval, "tetrapod_group" : tet_group,
                                                "sigma" : sim_params["sigma"], "speciation_rate" : sr,
                                                "deme" : sim_params["deme"], "richness" : r,
                                                "fragment" : fragment,
                                                "percent_cover": pc, "scenario" : scenario})
				
df = pd.DataFrame(tmp)
df_distance_sim = pd.DataFrame(distance_sim_tmp)
df_fragment_abundances = pd.DataFrame(fragment_abundances)
# Out:
# HBox(children=(IntProgress(value=0, description='Files', max=1170, style=ProgressStyle(description_width='init…

# %%
# Save the output to csv
src_csv = os.path.join(results_dir, "results_{}_occ_sq.csv".format(fragmented))
df.to_csv(src_csv, index=False)
src_csv2 = os.path.join(results_dir, "results_distance_sim_{}_occ_sq.csv".format(fragmented))
df_distance_sim.to_csv(src_csv2)
src_csv3 = os.path.join(results_dir, "results_fragment_abundances_{}_occ_sq.csv".format(fragmented))
df_fragment_abundances.to_csv(src_csv3)

# %%
# Move the output csvs - change fragmented variable as appropriate

if not os.path.exists(dst_folder):
	os.makedirs(dst_folder)
dst_csv = os.path.join(dst_folder, "results_{}_occ_sq.csv".format(fragmented))
dst_csv2 = os.path.join(dst_folder, "results_distance_sim_{}_occ_sq.csv".format(fragmented))
dst_csv3 = os.path.join(dst_folder, "results_fragment_abundances_{}_occ_sq.csv".format(fragmented))
shutil.copy2(src_csv, dst_csv)
shutil.copy2(src_csv2, dst_csv2)
shutil.copy2(src_csv3, dst_csv3)
# Out:
# '/home/sam/Documents/PhD/PaleoSampling/Results/PaleoMainOcc2/results_fragment_abundances_all_occ_sq.csv'

# %%
# Move the output csvs - change fragmented variable as appropriate
if not os.path.exists(dst_folder2):
	os.makedirs(dst_folder2)
dst_csv = os.path.join(dst_folder2, "results_{}_occ_sq.csv".format(fragmented))
dst_csv2 = os.path.join(dst_folder2, "results_distance_sim_{}_occ_sq.csv".format(fragmented))
dst_csv3 = os.path.join(dst_folder2, "results_fragment_abundances_{}_occ_sq.csv".format(fragmented))
shutil.copy2(src_csv, dst_csv)
shutil.copy2(src_csv2, dst_csv2)
shutil.copy2(src_csv3, dst_csv3)
# Out:
# '/home/sam/Documents/PhD/PaleoSampling/Code/MainSimulationR/results/PaleoMainOcc2/results_fragment_abundances_all_occ_sq.csv'

# %% [markdown]
# ## Verify that the data is sampling the correct number of individuals

# %%
fragment_df = pd.DataFrame(columns=["fragment", "xmin", "ymin", "xmax", "ymax", "total"])
for interval in intervals:
    for tet_group in tetrapod_groups:
        fragment_csv = pathlib.Path(data_dir, "configs",
                                            "fragments_occ_{}_{}.csv".format(interval, tet_group))
        tmp = pd.read_csv(fragment_csv, header=None, names=["fragment", "xmin", "ymin", "xmax", "ymax", "total"]).assign(interval=interval, tetrapod_group=tet_group)
        fragment_df = fragment_df.append(tmp, sort=False)
        
fragment_df = fragment_df.groupby(["interval", "tetrapod_group"])["total"].sum().reset_index()

# %%
for file in tqdm_notebook(os.listdir(results_dir), desc="Files"):
    file_path = os.path.join(results_dir, file)
    _, ext = os.path.splitext(file_path)
    if ".db" == ext:
        # print(file)
        t = CoalescenceTree(file_path)
        with SQLiteConnection(t.database) as c:
            max_n = c.execute("SELECT COUNT(*) FROM SPECIES_LIST_ORIGINAL_0 WHERE tip==1").fetchone()[0]
        sim_params = t.get_simulation_parameters()
        species_richness = t.get_species_richness(ref)
        beta = t.get_beta_diversity(ref)
        alpha = t.get_alpha_diversity(ref)
        scenario = sim_scenario_detection(file)
        goodness_fit = t.get_goodness_of_fit(reference=ref)
        total_ind = t.get_number_individuals(community_reference=ref)
        (interval, tet_group) = sim_type_detection(sim_params["sample_file"])
        n = t.get_number_individuals()
        expected_n = int(fragment_df[(fragment_df.interval == interval) & (fragment_df.tetrapod_group == tet_group)]["total"])
        if n != expected_n:
            logging.info(f"{n} != {expected_n} in {interval}, {tet_group} and max_ind = {max_n} in scenario {scenario}")
# Out:
# HBox(children=(IntProgress(value=0, description='Files', max=1112, style=ProgressStyle(description_width='init…
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 396 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 297 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 306 in scenario clustered
# INFO:root:93 != 1026 in artinskian, amphibian and max_ind = 99 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 600 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 306 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 306 in scenario clustered
# INFO:root:147 != 1026 in artinskian, amphibian and max_ind = 273 in scenario clustered
# INFO:root:149 != 1026 in artinskian, amphibian and max_ind = 288 in scenario clustered
# INFO:root:148 != 1026 in artinskian, amphibian and max_ind = 272 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 330 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 420 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 297 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 420 in scenario clustered
# INFO:root:145 != 1026 in artinskian, amphibian and max_ind = 252 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 330 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 330 in scenario clustered
# INFO:root:147 != 1026 in artinskian, amphibian and max_ind = 273 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 297 in scenario clustered
# INFO:root:89 != 1026 in artinskian, amphibian and max_ind = 90 in scenario clustered
# INFO:root:151 != 1026 in artinskian, amphibian and max_ind = 297 in scenario clustered
# INFO:root:148 != 1026 in artinskian, amphibian and max_ind = 272 in scenario clustered
# INFO:root:89 != 1026 in artinskian, amphibian and max_ind = 90 in scenario clustered
# INFO:root:145 != 1026 in artinskian, amphibian and max_ind = 252 in scenario clustered
# INFO:root:1 != 32 in moscovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:1 != 32 in moscovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:1 != 32 in moscovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:54 != 612 in sakmarian, amphibian and max_ind = 160 in scenario clustered
# INFO:root:20 != 612 in sakmarian, amphibian and max_ind = 20 in scenario clustered
# INFO:root:51 != 612 in sakmarian, amphibian and max_ind = 120 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 190 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 190 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 195 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 234 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 190 in scenario clustered
# INFO:root:53 != 612 in sakmarian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:54 != 612 in sakmarian, amphibian and max_ind = 160 in scenario clustered
# INFO:root:53 != 612 in sakmarian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 171 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 171 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 344 in scenario clustered
# INFO:root:53 != 612 in sakmarian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 344 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 234 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 171 in scenario clustered
# INFO:root:54 != 612 in sakmarian, amphibian and max_ind = 160 in scenario clustered
# INFO:root:22 != 612 in sakmarian, amphibian and max_ind = 22 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 344 in scenario clustered
# INFO:root:22 != 612 in sakmarian, amphibian and max_ind = 22 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 190 in scenario clustered
# INFO:root:55 != 612 in sakmarian, amphibian and max_ind = 195 in scenario clustered
# INFO:root:144 != 365 in asselian, amphibian and max_ind = 144 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 215 in scenario clustered
# INFO:root:144 != 365 in asselian, amphibian and max_ind = 144 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 285 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 215 in scenario clustered
# INFO:root:152 != 365 in asselian, amphibian and max_ind = 186 in scenario clustered
# INFO:root:135 != 365 in asselian, amphibian and max_ind = 143 in scenario clustered
# INFO:root:144 != 365 in asselian, amphibian and max_ind = 161 in scenario clustered
# INFO:root:152 != 365 in asselian, amphibian and max_ind = 162 in scenario clustered
# INFO:root:152 != 365 in asselian, amphibian and max_ind = 180 in scenario clustered
# INFO:root:144 != 365 in asselian, amphibian and max_ind = 144 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 244 in scenario clustered
# INFO:root:152 != 365 in asselian, amphibian and max_ind = 180 in scenario clustered
# INFO:root:151 != 365 in asselian, amphibian and max_ind = 155 in scenario clustered
# INFO:root:144 != 365 in asselian, amphibian and max_ind = 144 in scenario clustered
# INFO:root:152 != 365 in asselian, amphibian and max_ind = 162 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 215 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 285 in scenario clustered
# INFO:root:152 != 365 in asselian, amphibian and max_ind = 186 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 285 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 244 in scenario clustered
# INFO:root:144 != 365 in asselian, amphibian and max_ind = 161 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 244 in scenario clustered
# INFO:root:180 != 365 in asselian, amphibian and max_ind = 215 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 345 in scenario clustered
# INFO:root:170 != 728 in artinskian, amniote and max_ind = 264 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 345 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 396 in scenario clustered
# INFO:root:100 != 728 in artinskian, amniote and max_ind = 100 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 396 in scenario clustered
# INFO:root:174 != 728 in artinskian, amniote and max_ind = 240 in scenario clustered
# INFO:root:110 != 728 in artinskian, amniote and max_ind = 110 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 600 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 297 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 396 in scenario clustered
# INFO:root:110 != 728 in artinskian, amniote and max_ind = 110 in scenario clustered
# INFO:root:170 != 728 in artinskian, amniote and max_ind = 264 in scenario clustered
# INFO:root:100 != 728 in artinskian, amniote and max_ind = 100 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 297 in scenario clustered
# INFO:root:174 != 728 in artinskian, amniote and max_ind = 240 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 345 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 396 in scenario clustered
# INFO:root:170 != 728 in artinskian, amniote and max_ind = 264 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 345 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 345 in scenario clustered
# INFO:root:177 != 728 in artinskian, amniote and max_ind = 280 in scenario clustered
# INFO:root:181 != 728 in artinskian, amniote and max_ind = 345 in scenario clustered
# INFO:root:179 != 728 in artinskian, amniote and max_ind = 288 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 3258 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1600 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 2439 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1800 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1628 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 2168 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1800 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 2030 in scenario clustered
# INFO:root:1073 != 1490 in kungurian, amphibian and max_ind = 1424 in scenario clustered
# INFO:root:1064 != 1490 in kungurian, amphibian and max_ind = 1351 in scenario clustered
# INFO:root:1064 != 1490 in kungurian, amphibian and max_ind = 1351 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1890 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1632 in scenario clustered
# INFO:root:1033 != 1490 in kungurian, amphibian and max_ind = 1280 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1480 in scenario clustered
# INFO:root:1073 != 1490 in kungurian, amphibian and max_ind = 1544 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 2025 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1800 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1890 in scenario clustered
# INFO:root:1073 != 1490 in kungurian, amphibian and max_ind = 1424 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1628 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1600 in scenario clustered
# INFO:root:1082 != 1490 in kungurian, amphibian and max_ind = 1480 in scenario clustered
# INFO:root:1064 != 1490 in kungurian, amphibian and max_ind = 1351 in scenario clustered
# INFO:root:18 != 221 in sakmarian, amniote and max_ind = 22 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 25 in scenario clustered
# INFO:root:14 != 221 in sakmarian, amniote and max_ind = 14 in scenario clustered
# INFO:root:18 != 221 in sakmarian, amniote and max_ind = 18 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 36 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 25 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 36 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 28 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 36 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 36 in scenario clustered
# INFO:root:26 != 221 in sakmarian, amniote and max_ind = 56 in scenario clustered
# INFO:root:20 != 221 in sakmarian, amniote and max_ind = 20 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 28 in scenario clustered
# INFO:root:26 != 221 in sakmarian, amniote and max_ind = 56 in scenario clustered
# INFO:root:18 != 221 in sakmarian, amniote and max_ind = 24 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 28 in scenario clustered
# INFO:root:14 != 221 in sakmarian, amniote and max_ind = 14 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 25 in scenario clustered
# INFO:root:14 != 221 in sakmarian, amniote and max_ind = 14 in scenario clustered
# INFO:root:18 != 221 in sakmarian, amniote and max_ind = 24 in scenario clustered
# INFO:root:18 != 221 in sakmarian, amniote and max_ind = 18 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 36 in scenario clustered
# INFO:root:22 != 221 in sakmarian, amniote and max_ind = 36 in scenario clustered
# INFO:root:26 != 221 in sakmarian, amniote and max_ind = 56 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:9 != 137 in gzhelian, amphibian and max_ind = 12 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:9 != 137 in gzhelian, amphibian and max_ind = 12 in scenario clustered
# INFO:root:9 != 137 in gzhelian, amphibian and max_ind = 10 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:21 != 137 in gzhelian, amphibian and max_ind = 51 in scenario clustered
# INFO:root:21 != 137 in gzhelian, amphibian and max_ind = 51 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:8 != 137 in gzhelian, amphibian and max_ind = 8 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:9 != 137 in gzhelian, amphibian and max_ind = 10 in scenario clustered
# INFO:root:21 != 137 in gzhelian, amphibian and max_ind = 68 in scenario clustered
# INFO:root:21 != 137 in gzhelian, amphibian and max_ind = 51 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:9 != 137 in gzhelian, amphibian and max_ind = 10 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:1 != 137 in gzhelian, amphibian and max_ind = 1 in scenario clustered
# INFO:root:21 != 137 in gzhelian, amphibian and max_ind = 34 in scenario clustered
# INFO:root:21 != 137 in gzhelian, amphibian and max_ind = 68 in scenario clustered
# INFO:root:834 != 1032 in kungurian, amniote and max_ind = 1188 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1330 in scenario clustered
# INFO:root:831 != 1032 in kungurian, amniote and max_ind = 1044 in scenario clustered
# INFO:root:844 != 1032 in kungurian, amniote and max_ind = 1218 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1608 in scenario clustered
# INFO:root:844 != 1032 in kungurian, amniote and max_ind = 1218 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1330 in scenario clustered
# INFO:root:646 != 1032 in kungurian, amniote and max_ind = 670 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1612 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1197 in scenario clustered
# INFO:root:834 != 1032 in kungurian, amniote and max_ind = 1188 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1260 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1330 in scenario clustered
# INFO:root:664 != 1032 in kungurian, amniote and max_ind = 737 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1743 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1430 in scenario clustered
# INFO:root:834 != 1032 in kungurian, amniote and max_ind = 1188 in scenario clustered
# INFO:root:844 != 1032 in kungurian, amniote and max_ind = 1218 in scenario clustered
# INFO:root:755 != 1032 in kungurian, amniote and max_ind = 918 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1743 in scenario clustered
# INFO:root:843 != 1032 in kungurian, amniote and max_ind = 1120 in scenario clustered
# INFO:root:854 != 1032 in kungurian, amniote and max_ind = 1224 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 2432 in scenario clustered
# INFO:root:864 != 1032 in kungurian, amniote and max_ind = 1260 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:24 != 581 in moscovian, amphibian and max_ind = 105 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 112 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 147 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 112 in scenario clustered
# INFO:root:23 != 581 in moscovian, amphibian and max_ind = 98 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:24 != 581 in moscovian, amphibian and max_ind = 105 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 112 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:19 != 581 in moscovian, amphibian and max_ind = 70 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:21 != 581 in moscovian, amphibian and max_ind = 84 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 126 in scenario clustered
# INFO:root:19 != 581 in moscovian, amphibian and max_ind = 70 in scenario clustered
# INFO:root:25 != 581 in moscovian, amphibian and max_ind = 140 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 9 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 9 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 9 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 12 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 9 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 9 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:4 != 63 in kasimovian, amniote and max_ind = 8 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:1 != 63 in kasimovian, amniote and max_ind = 1 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 16 in scenario clustered
# INFO:root:1 != 113 in gzhelian, amniote and max_ind = 1 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 16 in scenario clustered
# INFO:root:19 != 113 in gzhelian, amniote and max_ind = 48 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 20 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 16 in scenario clustered
# INFO:root:1 != 113 in gzhelian, amniote and max_ind = 1 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 18 in scenario clustered
# INFO:root:19 != 113 in gzhelian, amniote and max_ind = 36 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 21 in scenario clustered
# INFO:root:1 != 113 in gzhelian, amniote and max_ind = 1 in scenario clustered
# INFO:root:19 != 113 in gzhelian, amniote and max_ind = 36 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 20 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 16 in scenario clustered
# INFO:root:1 != 113 in gzhelian, amniote and max_ind = 1 in scenario clustered
# INFO:root:19 != 113 in gzhelian, amniote and max_ind = 48 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 20 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 18 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 20 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 20 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 21 in scenario clustered
# INFO:root:19 != 113 in gzhelian, amniote and max_ind = 36 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 20 in scenario clustered
# INFO:root:16 != 113 in gzhelian, amniote and max_ind = 18 in scenario clustered
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario fragmented
# INFO:root:531 != 728 in artinskian, amniote and max_ind = 572 in scenario fragmented
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario fragmented
# INFO:root:531 != 728 in artinskian, amniote and max_ind = 572 in scenario fragmented
# INFO:root:509 != 728 in artinskian, amniote and max_ind = 520 in scenario fragmented
# INFO:root:223 != 365 in asselian, amphibian and max_ind = 230 in scenario fragmented
# INFO:root:231 != 365 in asselian, amphibian and max_ind = 231 in scenario fragmented
# INFO:root:268 != 365 in asselian, amphibian and max_ind = 275 in scenario fragmented
# INFO:root:256 != 365 in asselian, amphibian and max_ind = 256 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario fragmented
# INFO:root:260 != 365 in asselian, amphibian and max_ind = 264 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:239 != 365 in asselian, amphibian and max_ind = 253 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 320 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:239 != 365 in asselian, amphibian and max_ind = 253 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario fragmented
# INFO:root:260 != 365 in asselian, amphibian and max_ind = 264 in scenario fragmented
# INFO:root:268 != 365 in asselian, amphibian and max_ind = 275 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 320 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:231 != 365 in asselian, amphibian and max_ind = 231 in scenario fragmented
# INFO:root:223 != 365 in asselian, amphibian and max_ind = 230 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:98 != 113 in gzhelian, amniote and max_ind = 98 in scenario fragmented
# INFO:root:96 != 113 in gzhelian, amniote and max_ind = 96 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:93 != 113 in gzhelian, amniote and max_ind = 99 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario fragmented
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 152 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:103 != 113 in gzhelian, amniote and max_ind = 105 in scenario fragmented
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 110 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 130 in scenario fragmented
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 108 in scenario fragmented
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 112 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:42 != 56 in kasimovian, amphibian and max_ind = 42 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 69 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 54 in scenario fragmented
# INFO:root:37 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:42 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:37 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:38 != 56 in kasimovian, amphibian and max_ind = 44 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:36 != 56 in kasimovian, amphibian and max_ind = 36 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:40 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:42 != 56 in kasimovian, amphibian and max_ind = 42 in scenario fragmented
# INFO:root:37 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 69 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:38 != 56 in kasimovian, amphibian and max_ind = 44 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:36 != 56 in kasimovian, amphibian and max_ind = 36 in scenario fragmented
# INFO:root:40 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:37 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 54 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:42 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:850 != 1026 in artinskian, amphibian and max_ind = 946 in scenario fragmented
# INFO:root:1014 != 1026 in artinskian, amphibian and max_ind = 1512 in scenario fragmented
# INFO:root:833 != 1026 in artinskian, amphibian and max_ind = 860 in scenario fragmented
# INFO:root:850 != 1026 in artinskian, amphibian and max_ind = 946 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 160 in scenario fragmented
# INFO:root:98 != 137 in gzhelian, amphibian and max_ind = 110 in scenario fragmented
# INFO:root:108 != 137 in gzhelian, amphibian and max_ind = 120 in scenario fragmented
# INFO:root:104 != 137 in gzhelian, amphibian and max_ind = 104 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 135 in scenario fragmented
# INFO:root:98 != 137 in gzhelian, amphibian and max_ind = 98 in scenario fragmented
# INFO:root:106 != 137 in gzhelian, amphibian and max_ind = 126 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario fragmented
# INFO:root:105 != 137 in gzhelian, amphibian and max_ind = 112 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 120 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 138 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:110 != 137 in gzhelian, amphibian and max_ind = 115 in scenario fragmented
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:108 != 137 in gzhelian, amphibian and max_ind = 117 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:42 != 56 in kasimovian, amphibian and max_ind = 42 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 69 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:40 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:38 != 56 in kasimovian, amphibian and max_ind = 44 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:35 != 56 in kasimovian, amphibian and max_ind = 35 in scenario fragmented
# INFO:root:42 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 50 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 45 in scenario fragmented
# INFO:root:37 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:37 != 56 in kasimovian, amphibian and max_ind = 40 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 56 in scenario fragmented
# INFO:root:43 != 56 in kasimovian, amphibian and max_ind = 54 in scenario fragmented
# INFO:root:36 != 56 in kasimovian, amphibian and max_ind = 36 in scenario fragmented
# INFO:root:469 != 612 in sakmarian, amphibian and max_ind = 490 in scenario fragmented
# INFO:root:477 != 612 in sakmarian, amphibian and max_ind = 539 in scenario fragmented
# INFO:root:479 != 612 in sakmarian, amphibian and max_ind = 539 in scenario fragmented
# INFO:root:833 != 1026 in artinskian, amphibian and max_ind = 860 in scenario fragmented
# INFO:root:1014 != 1026 in artinskian, amphibian and max_ind = 1512 in scenario fragmented
# INFO:root:850 != 1026 in artinskian, amphibian and max_ind = 946 in scenario fragmented
# INFO:root:850 != 1026 in artinskian, amphibian and max_ind = 946 in scenario fragmented
# INFO:root:469 != 612 in sakmarian, amphibian and max_ind = 490 in scenario fragmented
# INFO:root:602 != 612 in sakmarian, amphibian and max_ind = 1029 in scenario fragmented
# INFO:root:477 != 612 in sakmarian, amphibian and max_ind = 539 in scenario fragmented
# INFO:root:482 != 612 in sakmarian, amphibian and max_ind = 539 in scenario fragmented
# INFO:root:477 != 612 in sakmarian, amphibian and max_ind = 539 in scenario fragmented
# INFO:root:602 != 612 in sakmarian, amphibian and max_ind = 1029 in scenario fragmented
# INFO:root:469 != 612 in sakmarian, amphibian and max_ind = 490 in scenario fragmented
# INFO:root:317 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 320 in scenario fragmented
# INFO:root:258 != 365 in asselian, amphibian and max_ind = 294 in scenario fragmented
# INFO:root:223 != 365 in asselian, amphibian and max_ind = 230 in scenario fragmented
# INFO:root:260 != 365 in asselian, amphibian and max_ind = 264 in scenario fragmented
# INFO:root:256 != 365 in asselian, amphibian and max_ind = 256 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 504 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:239 != 365 in asselian, amphibian and max_ind = 253 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario fragmented
# INFO:root:231 != 365 in asselian, amphibian and max_ind = 231 in scenario fragmented
# INFO:root:268 != 365 in asselian, amphibian and max_ind = 275 in scenario fragmented
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario fragmented
# INFO:root:531 != 728 in artinskian, amniote and max_ind = 572 in scenario fragmented
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario fragmented
# INFO:root:531 != 728 in artinskian, amniote and max_ind = 572 in scenario fragmented
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario fragmented
# INFO:root:509 != 728 in artinskian, amniote and max_ind = 520 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 84 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario fragmented
# INFO:root:64 != 85 in asselian, amniote and max_ind = 66 in scenario fragmented
# INFO:root:59 != 85 in asselian, amniote and max_ind = 60 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 80 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:59 != 85 in asselian, amniote and max_ind = 60 in scenario fragmented
# INFO:root:68 != 85 in asselian, amniote and max_ind = 72 in scenario fragmented
# INFO:root:69 != 85 in asselian, amniote and max_ind = 70 in scenario fragmented
# INFO:root:76 != 85 in asselian, amniote and max_ind = 78 in scenario fragmented
# INFO:root:64 != 85 in asselian, amniote and max_ind = 64 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 123 in scenario fragmented
# INFO:root:68 != 85 in asselian, amniote and max_ind = 77 in scenario fragmented
# INFO:root:63 != 85 in asselian, amniote and max_ind = 63 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 72 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 72 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 72 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:76 != 85 in asselian, amniote and max_ind = 78 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 84 in scenario fragmented
# INFO:root:68 != 85 in asselian, amniote and max_ind = 72 in scenario fragmented
# INFO:root:59 != 85 in asselian, amniote and max_ind = 60 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:64 != 85 in asselian, amniote and max_ind = 66 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 72 in scenario fragmented
# INFO:root:70 != 85 in asselian, amniote and max_ind = 80 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 123 in scenario fragmented
# INFO:root:64 != 85 in asselian, amniote and max_ind = 64 in scenario fragmented
# INFO:root:63 != 85 in asselian, amniote and max_ind = 63 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario fragmented
# INFO:root:68 != 85 in asselian, amniote and max_ind = 77 in scenario fragmented
# INFO:root:69 != 85 in asselian, amniote and max_ind = 70 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 65 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 55 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 49 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 69 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 56 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 78 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 75 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 54 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario fragmented
# INFO:root:48 != 63 in kasimovian, amniote and max_ind = 48 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario fragmented
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 77 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario fragmented
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 92 in scenario fragmented
# INFO:root:1480 != 1490 in kungurian, amphibian and max_ind = 2040 in scenario fragmented
# INFO:root:1470 != 1490 in kungurian, amphibian and max_ind = 1932 in scenario fragmented
# INFO:root:1479 != 1490 in kungurian, amphibian and max_ind = 2040 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 152 in scenario fragmented
# INFO:root:103 != 113 in gzhelian, amniote and max_ind = 105 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 114 in scenario fragmented
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 108 in scenario fragmented
# INFO:root:98 != 113 in gzhelian, amniote and max_ind = 98 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 126 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 126 in scenario fragmented
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 130 in scenario fragmented
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 112 in scenario fragmented
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 110 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario fragmented
# INFO:root:96 != 113 in gzhelian, amniote and max_ind = 96 in scenario fragmented
# INFO:root:93 != 113 in gzhelian, amniote and max_ind = 99 in scenario fragmented
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario fragmented
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 175 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario fragmented
# INFO:root:205 != 221 in sakmarian, amniote and max_ind = 250 in scenario fragmented
# INFO:root:161 != 221 in sakmarian, amniote and max_ind = 161 in scenario fragmented
# INFO:root:160 != 221 in sakmarian, amniote and max_ind = 160 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 268 in scenario fragmented
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 184 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 200 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario fragmented
# INFO:root:159 != 221 in sakmarian, amniote and max_ind = 165 in scenario fragmented
# INFO:root:147 != 221 in sakmarian, amniote and max_ind = 150 in scenario fragmented
# INFO:root:1481 != 1490 in kungurian, amphibian and max_ind = 2040 in scenario fragmented
# INFO:root:160 != 221 in sakmarian, amniote and max_ind = 160 in scenario fragmented
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 184 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 200 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario fragmented
# INFO:root:147 != 221 in sakmarian, amniote and max_ind = 150 in scenario fragmented
# INFO:root:205 != 221 in sakmarian, amniote and max_ind = 268 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario fragmented
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 175 in scenario fragmented
# INFO:root:159 != 221 in sakmarian, amniote and max_ind = 165 in scenario fragmented
# INFO:root:161 != 221 in sakmarian, amniote and max_ind = 161 in scenario fragmented
# INFO:root:159 != 221 in sakmarian, amniote and max_ind = 165 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario fragmented
# INFO:root:147 != 221 in sakmarian, amniote and max_ind = 150 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 210 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 324 in scenario fragmented
# INFO:root:161 != 221 in sakmarian, amniote and max_ind = 161 in scenario fragmented
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 268 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario fragmented
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 175 in scenario fragmented
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 184 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario fragmented
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario fragmented
# INFO:root:170 != 221 in sakmarian, amniote and max_ind = 196 in scenario fragmented
# INFO:root:177 != 221 in sakmarian, amniote and max_ind = 200 in scenario fragmented
# INFO:root:160 != 221 in sakmarian, amniote and max_ind = 160 in scenario fragmented
# INFO:root:850 != 1026 in artinskian, amphibian and max_ind = 946 in scenario fragmented
# INFO:root:850 != 1026 in artinskian, amphibian and max_ind = 946 in scenario fragmented
# INFO:root:1014 != 1026 in artinskian, amphibian and max_ind = 1512 in scenario fragmented
# INFO:root:833 != 1026 in artinskian, amphibian and max_ind = 860 in scenario fragmented
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario fragmented
# INFO:root:108 != 137 in gzhelian, amphibian and max_ind = 117 in scenario fragmented
# INFO:root:98 != 137 in gzhelian, amphibian and max_ind = 110 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:104 != 137 in gzhelian, amphibian and max_ind = 104 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 120 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 135 in scenario fragmented
# INFO:root:105 != 137 in gzhelian, amphibian and max_ind = 112 in scenario fragmented
# INFO:root:98 != 137 in gzhelian, amphibian and max_ind = 98 in scenario fragmented
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 160 in scenario fragmented
# INFO:root:110 != 137 in gzhelian, amphibian and max_ind = 115 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario fragmented
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario fragmented
# INFO:root:64 != 85 in asselian, amniote and max_ind = 66 in scenario fragmented
# ...
# INFO:root:36 != 56 in kasimovian, amphibian and max_ind = 36 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 35 in scenario pristine
# INFO:root:25 != 32 in moscovian, amniote and max_ind = 30 in scenario pristine
# INFO:root:24 != 32 in moscovian, amniote and max_ind = 24 in scenario pristine
# INFO:root:21 != 32 in moscovian, amniote and max_ind = 21 in scenario pristine
# INFO:root:19 != 32 in moscovian, amniote and max_ind = 20 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 36 in scenario pristine
# INFO:root:27 != 32 in moscovian, amniote and max_ind = 27 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 36 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 35 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 35 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 35 in scenario pristine
# INFO:root:20 != 32 in moscovian, amniote and max_ind = 22 in scenario pristine
# INFO:root:18 != 32 in moscovian, amniote and max_ind = 18 in scenario pristine
# INFO:root:24 != 32 in moscovian, amniote and max_ind = 25 in scenario pristine
# INFO:root:21 != 32 in moscovian, amniote and max_ind = 21 in scenario pristine
# INFO:root:25 != 32 in moscovian, amniote and max_ind = 27 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 45 in scenario pristine
# INFO:root:19 != 32 in moscovian, amniote and max_ind = 20 in scenario pristine
# INFO:root:25 != 32 in moscovian, amniote and max_ind = 27 in scenario pristine
# INFO:root:21 != 32 in moscovian, amniote and max_ind = 21 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 36 in scenario pristine
# INFO:root:29 != 32 in moscovian, amniote and max_ind = 36 in scenario pristine
# INFO:root:595 != 612 in sakmarian, amphibian and max_ind = 876 in scenario pristine
# INFO:root:602 != 612 in sakmarian, amphibian and max_ind = 1029 in scenario pristine
# INFO:root:469 != 612 in sakmarian, amphibian and max_ind = 490 in scenario pristine
# INFO:root:597 != 612 in sakmarian, amphibian and max_ind = 984 in scenario pristine
# INFO:root:601 != 612 in sakmarian, amphibian and max_ind = 992 in scenario pristine
# INFO:root:602 != 612 in sakmarian, amphibian and max_ind = 1029 in scenario pristine
# INFO:root:602 != 612 in sakmarian, amphibian and max_ind = 1022 in scenario pristine
# INFO:root:602 != 612 in sakmarian, amphibian and max_ind = 1029 in scenario pristine
# INFO:root:611 != 612 in sakmarian, amphibian and max_ind = 1116 in scenario pristine
# INFO:root:610 != 612 in sakmarian, amphibian and max_ind = 1116 in scenario pristine
# INFO:root:469 != 612 in sakmarian, amphibian and max_ind = 490 in scenario pristine
# INFO:root:477 != 612 in sakmarian, amphibian and max_ind = 539 in scenario pristine
# INFO:root:479 != 612 in sakmarian, amphibian and max_ind = 539 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario pristine
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 330 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario pristine
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 320 in scenario pristine
# INFO:root:258 != 365 in asselian, amphibian and max_ind = 294 in scenario pristine
# INFO:root:223 != 365 in asselian, amphibian and max_ind = 230 in scenario pristine
# INFO:root:260 != 365 in asselian, amphibian and max_ind = 264 in scenario pristine
# INFO:root:256 != 365 in asselian, amphibian and max_ind = 256 in scenario pristine
# INFO:root:305 != 365 in asselian, amphibian and max_ind = 321 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 504 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario pristine
# INFO:root:239 != 365 in asselian, amphibian and max_ind = 253 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 428 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario pristine
# INFO:root:316 != 365 in asselian, amphibian and max_ind = 380 in scenario pristine
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario pristine
# INFO:root:223 != 365 in asselian, amphibian and max_ind = 230 in scenario pristine
# INFO:root:231 != 365 in asselian, amphibian and max_ind = 231 in scenario pristine
# INFO:root:268 != 365 in asselian, amphibian and max_ind = 275 in scenario pristine
# INFO:root:272 != 365 in asselian, amphibian and max_ind = 288 in scenario pristine
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario pristine
# INFO:root:531 != 728 in artinskian, amniote and max_ind = 572 in scenario pristine
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario pristine
# INFO:root:531 != 728 in artinskian, amniote and max_ind = 572 in scenario pristine
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario pristine
# INFO:root:703 != 728 in artinskian, amniote and max_ind = 984 in scenario pristine
# INFO:root:707 != 728 in artinskian, amniote and max_ind = 1014 in scenario pristine
# INFO:root:509 != 728 in artinskian, amniote and max_ind = 520 in scenario pristine
# INFO:root:714 != 728 in artinskian, amniote and max_ind = 1064 in scenario pristine
# INFO:root:509 != 728 in artinskian, amniote and max_ind = 520 in scenario pristine
# INFO:root:705 != 728 in artinskian, amniote and max_ind = 912 in scenario pristine
# INFO:root:70 != 85 in asselian, amniote and max_ind = 72 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario pristine
# INFO:root:76 != 85 in asselian, amniote and max_ind = 78 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario pristine
# INFO:root:70 != 85 in asselian, amniote and max_ind = 84 in scenario pristine
# INFO:root:68 != 85 in asselian, amniote and max_ind = 72 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario pristine
# INFO:root:59 != 85 in asselian, amniote and max_ind = 60 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 104 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario pristine
# INFO:root:64 != 85 in asselian, amniote and max_ind = 66 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario pristine
# INFO:root:70 != 85 in asselian, amniote and max_ind = 72 in scenario pristine
# INFO:root:59 != 85 in asselian, amniote and max_ind = 60 in scenario pristine
# INFO:root:70 != 85 in asselian, amniote and max_ind = 80 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 123 in scenario pristine
# INFO:root:64 != 85 in asselian, amniote and max_ind = 64 in scenario pristine
# INFO:root:63 != 85 in asselian, amniote and max_ind = 63 in scenario pristine
# INFO:root:78 != 85 in asselian, amniote and max_ind = 95 in scenario pristine
# INFO:root:68 != 85 in asselian, amniote and max_ind = 77 in scenario pristine
# INFO:root:69 != 85 in asselian, amniote and max_ind = 70 in scenario pristine
# INFO:root:1480 != 1490 in kungurian, amphibian and max_ind = 2040 in scenario pristine
# INFO:root:1470 != 1490 in kungurian, amphibian and max_ind = 1932 in scenario pristine
# INFO:root:160 != 221 in sakmarian, amniote and max_ind = 160 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 268 in scenario pristine
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 184 in scenario pristine
# INFO:root:147 != 221 in sakmarian, amniote and max_ind = 150 in scenario pristine
# INFO:root:197 != 221 in sakmarian, amniote and max_ind = 201 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 324 in scenario pristine
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario pristine
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 210 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario pristine
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 200 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 268 in scenario pristine
# INFO:root:170 != 221 in sakmarian, amniote and max_ind = 196 in scenario pristine
# INFO:root:147 != 221 in sakmarian, amniote and max_ind = 150 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 268 in scenario pristine
# INFO:root:176 != 221 in sakmarian, amniote and max_ind = 180 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario pristine
# INFO:root:172 != 221 in sakmarian, amniote and max_ind = 175 in scenario pristine
# INFO:root:159 != 221 in sakmarian, amniote and max_ind = 165 in scenario pristine
# INFO:root:204 != 221 in sakmarian, amniote and max_ind = 250 in scenario pristine
# INFO:root:161 != 221 in sakmarian, amniote and max_ind = 161 in scenario pristine
# INFO:root:108 != 137 in gzhelian, amphibian and max_ind = 120 in scenario pristine
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario pristine
# INFO:root:105 != 137 in gzhelian, amphibian and max_ind = 112 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 160 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario pristine
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario pristine
# INFO:root:96 != 137 in gzhelian, amphibian and max_ind = 100 in scenario pristine
# INFO:root:110 != 137 in gzhelian, amphibian and max_ind = 115 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario pristine
# INFO:root:106 != 137 in gzhelian, amphibian and max_ind = 126 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 160 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario pristine
# INFO:root:98 != 137 in gzhelian, amphibian and max_ind = 98 in scenario pristine
# INFO:root:104 != 137 in gzhelian, amphibian and max_ind = 104 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 138 in scenario pristine
# INFO:root:98 != 137 in gzhelian, amphibian and max_ind = 110 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 140 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 120 in scenario pristine
# INFO:root:112 != 137 in gzhelian, amphibian and max_ind = 135 in scenario pristine
# INFO:root:108 != 137 in gzhelian, amphibian and max_ind = 117 in scenario pristine
# INFO:root:990 != 1032 in kungurian, amniote and max_ind = 1266 in scenario pristine
# INFO:root:1006 != 1032 in kungurian, amniote and max_ind = 1477 in scenario pristine
# INFO:root:726 != 1032 in kungurian, amniote and max_ind = 750 in scenario pristine
# INFO:root:752 != 1032 in kungurian, amniote and max_ind = 825 in scenario pristine
# INFO:root:752 != 1032 in kungurian, amniote and max_ind = 825 in scenario pristine
# INFO:root:726 != 1032 in kungurian, amniote and max_ind = 750 in scenario pristine
# INFO:root:1006 != 1032 in kungurian, amniote and max_ind = 1477 in scenario pristine
# INFO:root:1000 != 1032 in kungurian, amniote and max_ind = 1368 in scenario pristine
# INFO:root:1006 != 1032 in kungurian, amniote and max_ind = 1477 in scenario pristine
# INFO:root:1006 != 1032 in kungurian, amniote and max_ind = 1477 in scenario pristine
# INFO:root:993 != 1032 in kungurian, amniote and max_ind = 1422 in scenario pristine
# INFO:root:577 != 581 in moscovian, amphibian and max_ind = 812 in scenario pristine
# INFO:root:569 != 581 in moscovian, amphibian and max_ind = 720 in scenario pristine
# INFO:root:577 != 581 in moscovian, amphibian and max_ind = 798 in scenario pristine
# INFO:root:569 != 581 in moscovian, amphibian and max_ind = 720 in scenario pristine
# INFO:root:570 != 581 in moscovian, amphibian and max_ind = 715 in scenario pristine
# INFO:root:569 != 581 in moscovian, amphibian and max_ind = 720 in scenario pristine
# INFO:root:571 != 581 in moscovian, amphibian and max_ind = 792 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 92 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 56 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 55 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 49 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 77 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 92 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 78 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 65 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 75 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 54 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 69 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario pristine
# INFO:root:49 != 63 in kasimovian, amniote and max_ind = 50 in scenario pristine
# INFO:root:61 != 63 in kasimovian, amniote and max_ind = 80 in scenario pristine
# INFO:root:48 != 63 in kasimovian, amniote and max_ind = 48 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario pristine
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 126 in scenario pristine
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 112 in scenario pristine
# INFO:root:93 != 113 in gzhelian, amniote and max_ind = 99 in scenario pristine
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 110 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 152 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 126 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 130 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario pristine
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario pristine
# INFO:root:103 != 113 in gzhelian, amniote and max_ind = 105 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 152 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 114 in scenario pristine
# INFO:root:96 != 113 in gzhelian, amniote and max_ind = 96 in scenario pristine
# INFO:root:98 != 113 in gzhelian, amniote and max_ind = 98 in scenario pristine
# INFO:root:101 != 113 in gzhelian, amniote and max_ind = 108 in scenario pristine
# INFO:root:89 != 113 in gzhelian, amniote and max_ind = 90 in scenario pristine
# INFO:root:105 != 113 in gzhelian, amniote and max_ind = 135 in scenario pristine

# %%
interval, tet_group
# Out:
# ('artinskian', 'amphibian')

# %%
int(fragment_df[(fragment_df.interval == interval) & (fragment_df.tetrapod_group == tet_group)]["total"])
# Out:
# 1026

# %%
df.head()
# Out:
#    actual_alpha  actual_beta  actual_richness  alpha_diversity  \
# 0      2.307692    32.933333             76.0         2.446154
# 1      2.307692    32.933333             76.0         2.461538
# 2      2.307692    32.933333             76.0         2.369231
# 3      2.307692    32.933333             76.0         2.523077
# 4      2.307692    32.933333             76.0         2.476923
#
#    beta_diversity        deme       gof    interval  percent_cover  richness  \
# 0       64.591195  342.571843  0.692738  artinskian            0.8       158
# 1       30.468750  342.571843  0.927043  artinskian            0.8        75
# 2       40.519481  342.571843  0.855374  artinskian            0.8        96
# 3       44.390244  342.571843  0.804110  artinskian            0.8       112
# 4       50.869565  342.571843  0.759140  artinskian            0.8       126
#
#      scenario     sigma  simulated_individuals  speciation_rate tetrapod_group
# 0  fragmented  0.690367                    728     1.000000e-08        amniote
# 1  fragmented  0.690367                    728     1.000000e-09        amniote
# 2  fragmented  0.690367                    728     2.000000e-09        amniote
# 3  fragmented  0.690367                    728     3.000000e-09        amniote
# 4  fragmented  0.690367                    728     4.000000e-09        amniote

# %%
(df[df.tetrapod_group == "amphibian"][["deme", "interval", "scenario", "tetrapod_group"]]
 .groupby(["interval", "scenario", "tetrapod_group"]).size())
# Out:
# interval    scenario    tetrapod_group
# artinskian  clustered   amphibian         240
#             fragmented  amphibian         160
#             pristine    amphibian          50
# asselian    clustered   amphibian         240
#             fragmented  amphibian         450
#             pristine    amphibian         150
# bashkirian  pristine    amphibian          80
# gzhelian    clustered   amphibian         240
#             fragmented  amphibian         580
#             pristine    amphibian         200
# kasimovian  fragmented  amphibian         710
#             pristine    amphibian         230
# kungurian   clustered   amphibian         240
#             fragmented  amphibian         130
#             pristine    amphibian          20
# moscovian   clustered   amphibian         240
#             pristine    amphibian         130
# sakmarian   clustered   amphibian         240
#             fragmented  amphibian         130
#             pristine    amphibian          40
# dtype: int64

# %%
tmp = []
distance_sim_tmp = []
fragment_abundances = []
for file in tqdm_notebook(os.listdir(results_dir), desc="Files"):
    file_path = os.path.join(results_dir, file)
    _, ext = os.path.splitext(file_path)
    if ".db" == ext:
        # print(file)
        t = CoalescenceTree(file_path)
#         if check_sql_table_exist(t.database, "SPECIES_DISTANCE_SIMILARITY"):
#             t.cursor.execute("DROP TABLE IF EXISTS SPECIES_DISTANCE_SIMILARITY")
#         t.calculate_species_distance_similarity()
#         if not check_sql_table_exist(t.database, "BIODIVERSITY_METRICS"):
#             logging.warning("Skipping {} as BIODIVERSITY_METRICS table doesn't exist.".format(file))
#             continue
        for sr in speciation_rates:
                sim_params = t.get_simulation_parameters()
#                 species_richness = t.get_species_richness(ref)
#                 beta = t.get_beta_diversity(ref)
#                 alpha = t.get_alpha_diversity(ref)
#                 goodness_fit = t.get_goodness_of_fit(reference=ref)
                total_ind = t.get_number_individuals(community_reference=ref)
                (interval, tet_group) = sim_type_detection(sim_params["sample_file"])
                scenario = None
                
                for i in ["fragmented", "clustered", "pristine"]:
                    if i in file:
                        scenario = i
                        break
                if scenario == "fragmented":
                    pc = percent_cover_detection(sim_params["fine_map_file"])
                else:
                    pc = 1.0
                tmp.append({"interval": interval, "tetrapod_group" : tet_group,
                            "sigma" : sim_params["sigma"], "speciation_rate" : sr,
                            "deme" : sim_params["deme"], "job_type" : sim_params["job_type"],
                            "seed" : sim_params["seed"],
                            "percent_cover": pc, "simulated_individuals" : total_ind, "scenario" : scenario})
#                 # try:
#                 distance_sim = t.get_species_distance_similarity(ref)
#                 for distance, no_ind in distance_sim:
#                     distance_sim_tmp.append({"interval": interval, "tetrapod_group" : tet_group,
#                                              "sigma" : sim_params["sigma"], "speciation_rate" : sr,
#                             "deme" : sim_params["deme"], "richness" : species_richness,
#                             "beta_diversity" : beta, "alpha_diversity" : alpha,
#                             "gof" : goodness_fit, "actual_richness" : spec_r, "actual_beta" : b,
#                             "actual_alpha" : a, "distance" : distance, "no_individuals" : no_ind,"percent_cover": pc, "scenario" : scenario})
#                 for fragment in t.get_fragment_list(ref):
#                     r = t.get_fragment_richness(fragment, ref)
#                     fragment_abundances.append({"interval": interval, "tetrapod_group" : tet_group,
#                                                 "sigma" : sim_params["sigma"], "speciation_rate" : sr,
#                                                 "deme" : sim_params["deme"], "richness" : r,
#                                                 "fragment" : fragment,
#                                                 "percent_cover": pc, "scenario" : scenario})
				
tmp_df = pd.DataFrame(tmp)
# Out:
# HBox(children=(IntProgress(value=0, description='Files', max=1112, style=ProgressStyle(description_width='init…

# %%
tmp_df[(tmp_df.interval == "artinksian") & (tmp_df.scenario == "pristine") & (tmp_df.tetrapod_group == "amphibian")]
# Out:
# Empty DataFrame
# Columns: [deme, interval, job_type, percent_cover, scenario, seed, sigma, simulated_individuals, speciation_rate, tetrapod_group]
# Index: []

# %%
max_density = OrderedDict([(('artinskian', 'amniote'), 225),
                           (('artinskian', 'amphibian'), 225),
                           (('asselian', 'amniote'), 36),
                           (('asselian', 'amphibian'), 36),
                           (('bashkirian', 'amniote'), 1),
                           (('bashkirian', 'amphibian'), 529),
                           (('gzhelian', 'amniote'), 49),
                           (('gzhelian', 'amphibian'), 49),
                           (('kasimovian', 'amniote'), 49),
                           (('kasimovian', 'amphibian'), 16),
                           (('kungurian', 'amniote'), 225),
                           (('kungurian', 'amphibian'), 289),
                           (('moscovian', 'amniote'), 16),
                           (('moscovian', 'amphibian'), 441),
                           (('sakmarian', 'amniote'), 36),
                           (('sakmarian', 'amphibian'), 225)])

intervals = ["artinskian", "asselian", "bashkirian", "gzhelian", "kasimovian", "kungurian", "moscovian", "sakmarian"]
import lhsmdu

tetrapod_groups = ["amniote", "amphibian"]
def get_sim_parameters(job_num, save_dir, sim_type="pristine", param_list=None):
    """
	Gets the sim parameters, returned as a dictionary.

	:param job_num: the value passed in sys.argv
	:param save_dir: the directory to save the sim output to
	:return: dictionary containing the simulation parameters
	"""
    sim_list = []
    job_type = 1
    proportion_covers = [20, 40, 80] if sim_type == "fragmented" else [100]
    for proportion_cover in proportion_covers:
        for interval in intervals:
            for tetra_group in tetrapod_groups:
                job_type += 1
                for seed in range(1, 26, 1):
                    sim_list.append([interval, tetra_group, seed, job_type, proportion_cover])
    this_sim = sim_list[job_num]
    _, _, sigma, density_per_km = choose_sim_variables(this_sim[2], dimensions=2, param_list=param_list)
    density_per_km = 10 ** density_per_km
    return {
        "interval": this_sim[0],
        "tetrapod_group": this_sim[1],
        "sigma": sigma,
        "seed": this_sim[2],
        "job_type": this_sim[3],
        "density_per_km": density_per_km,
        "proportion_cover" : this_sim[4],
        "output_directory": os.path.join(save_dir, str(this_sim[3])),
    }

def choose_sim_variables(job_num, dimensions=2, param_list=None):
    """
	Choose the relevant simulation variables given the command-line argument
	:param job_num: the command-line argument for setting the task
	:return: a list containing the important dispersal parameters
	"""
    # job_type = int(job_num) % 5 # For latin hypercube sampling every job type is different
    job_type = job_num
    if param_list is None:
        if dimensions == 2:
            param_list = latin_two_dimensional_sampling(0.1, 20, 1.4, 3, 25)
        elif dimensions == 3:
            param_list = latin_three_dimensional_sampling(0.1, 8.0, 3.0, 10.0, 10, 6400, 100)
    if dimensions == 2:
        return [job_num, job_type, param_list[0, job_num], param_list[1, job_num]]
    elif dimensions == 3:
        return [job_num, job_type, param_list[0, job_num], param_list[1, job_num], param_list[2, job_num]]
    raise ValueError("Dimensions must be 2 or 3 currently.")
    

def latin_two_dimensional_sampling(dim_1_min, dim_1_max, dim_2_min, dim_2_max, number):
    """
	Samples efficiently and completely from the parameter space specified. Returns a list of pairs of parameters which
	simulations should run with.

	:param dim_1_min: the minimum value of the first dimension
	:param dim_1_max: the maximum value of the first dimension
	:param dim_2_min: the minimum value of the second dimension
	:param dim_2_max: the maximum value of the second dimension
	:param number: the number of samples to draw in each dimension

	:return: a list of parameter pairs generated using the lhsmdu module.
	:rtype list
	"""
    samples = lhsmdu.sample(2, number, randomSeed=1001)
    assert dim_1_min < dim_1_max
    assert dim_2_min < dim_2_max
    samples[0] = (dim_1_max - dim_1_min) * samples[0] + dim_1_min
    samples[1] = (dim_2_max - dim_2_min) * samples[1] + dim_2_min
    return samples

# %%
params = []
param_list = latin_two_dimensional_sampling(0.1, 20, 1.4, 3, 25)
for i in range(1, 1400):
    
    try:
        p = get_sim_parameters(i, "none", param_list = param_list, sim_type="fragmented")
        p["pbs"] = i
        params.append(p)
    except:
        continue
tmp_df = pd.DataFrame(params)

# %%
tmp_df["filename"] = tmp_df.apply(lambda x: "pristine_{}_{}.db".format(x["job_type"], x["seed"]), axis=1)
tmp_df
# Out:
#       density_per_km    interval  job_type output_directory   pbs  \
# 0         121.998706  artinskian         2           none/2     1
# 1          89.141170  artinskian         2           none/2     2
# 2         476.047838  artinskian         2           none/2     3
# 3         944.345234  artinskian         2           none/2     4
# 4         134.240159  artinskian         2           none/2     5
# 5          26.429407  artinskian         2           none/2     6
# 6         342.571843  artinskian         2           none/2     7
# 7         258.848859  artinskian         2           none/2     8
# 8          53.290374  artinskian         2           none/2     9
# 9         706.745869  artinskian         2           none/2    10
# 10         34.424688  artinskian         2           none/2    11
# 11         69.095997  artinskian         2           none/2    12
# 12        177.335194  artinskian         2           none/2    13
# 13        101.868488  artinskian         2           none/2    14
# 14        300.588978  artinskian         2           none/2    15
# 15         40.402603  artinskian         2           none/2    16
# 16        205.256155  artinskian         2           none/2    17
# 17        571.069857  artinskian         2           none/2    18
# 18        813.124660  artinskian         2           none/2    19
# 19        491.604989  artinskian         2           none/2    20
# 20         30.381943  artinskian         2           none/2    21
# 21        396.589951  artinskian         2           none/2    22
# 22         74.277955  artinskian         2           none/2    23
# 23         45.863370  artinskian         3           none/3    25
# 24        121.998706  artinskian         3           none/3    26
# 25         89.141170  artinskian         3           none/3    27
# 26        476.047838  artinskian         3           none/3    28
# 27        944.345234  artinskian         3           none/3    29
# 28        134.240159  artinskian         3           none/3    30
# 29         26.429407  artinskian         3           none/3    31
# ...              ...         ...       ...              ...   ...
# 1121      571.069857   sakmarian        48          none/48  1168
# 1122      813.124660   sakmarian        48          none/48  1169
# 1123      491.604989   sakmarian        48          none/48  1170
# 1124       30.381943   sakmarian        48          none/48  1171
# 1125      396.589951   sakmarian        48          none/48  1172
# 1126       74.277955   sakmarian        48          none/48  1173
# 1127       45.863370   sakmarian        49          none/49  1175
# 1128      121.998706   sakmarian        49          none/49  1176
# 1129       89.141170   sakmarian        49          none/49  1177
# 1130      476.047838   sakmarian        49          none/49  1178
# 1131      944.345234   sakmarian        49          none/49  1179
# 1132      134.240159   sakmarian        49          none/49  1180
# 1133       26.429407   sakmarian        49          none/49  1181
# 1134      342.571843   sakmarian        49          none/49  1182
# 1135      258.848859   sakmarian        49          none/49  1183
# 1136       53.290374   sakmarian        49          none/49  1184
# 1137      706.745869   sakmarian        49          none/49  1185
# 1138       34.424688   sakmarian        49          none/49  1186
# 1139       69.095997   sakmarian        49          none/49  1187
# 1140      177.335194   sakmarian        49          none/49  1188
# 1141      101.868488   sakmarian        49          none/49  1189
# 1142      300.588978   sakmarian        49          none/49  1190
# 1143       40.402603   sakmarian        49          none/49  1191
# 1144      205.256155   sakmarian        49          none/49  1192
# 1145      571.069857   sakmarian        49          none/49  1193
# 1146      813.124660   sakmarian        49          none/49  1194
# 1147      491.604989   sakmarian        49          none/49  1195
# 1148       30.381943   sakmarian        49          none/49  1196
# 1149      396.589951   sakmarian        49          none/49  1197
# 1150       74.277955   sakmarian        49          none/49  1198
#
#       proportion_cover  seed      sigma tetrapod_group           filename
# 0                   20     2  16.119937        amniote    pristine_2_2.db
# 1                   20     3   2.766267        amniote    pristine_2_3.db
# 2                   20     4   8.508750        amniote    pristine_2_4.db
# 3                   20     5  18.225811        amniote    pristine_2_5.db
# 4                   20     6  19.340737        amniote    pristine_2_6.db
# 5                   20     7  16.824312        amniote    pristine_2_7.db
# 6                   20     8   0.690367        amniote    pristine_2_8.db
# 7                   20     9   7.681397        amniote    pristine_2_9.db
# 8                   20    10   6.710675        amniote   pristine_2_10.db
# 9                   20    11   1.337784        amniote   pristine_2_11.db
# 10                  20    12   4.724173        amniote   pristine_2_12.db
# 11                  20    13  15.739642        amniote   pristine_2_13.db
# 12                  20    14  11.861039        amniote   pristine_2_14.db
# 13                  20    15  11.164857        amniote   pristine_2_15.db
# 14                  20    16  14.419014        amniote   pristine_2_16.db
# 15                  20    17  13.086114        amniote   pristine_2_17.db
# 16                  20    18  10.162626        amniote   pristine_2_18.db
# 17                  20    19  15.130138        amniote   pristine_2_19.db
# 18                  20    20   9.336330        amniote   pristine_2_20.db
# 19                  20    21  12.418583        amniote   pristine_2_21.db
# 20                  20    22   3.655674        amniote   pristine_2_22.db
# 21                  20    23   5.125564        amniote   pristine_2_23.db
# 22                  20    24  18.941445        amniote   pristine_2_24.db
# 23                  20     1   2.131084      amphibian    pristine_3_1.db
# 24                  20     2  16.119937      amphibian    pristine_3_2.db
# 25                  20     3   2.766267      amphibian    pristine_3_3.db
# 26                  20     4   8.508750      amphibian    pristine_3_4.db
# 27                  20     5  18.225811      amphibian    pristine_3_5.db
# 28                  20     6  19.340737      amphibian    pristine_3_6.db
# 29                  20     7  16.824312      amphibian    pristine_3_7.db
# ...                ...   ...        ...            ...                ...
# 1121                80    19  15.130138        amniote  pristine_48_19.db
# 1122                80    20   9.336330        amniote  pristine_48_20.db
# 1123                80    21  12.418583        amniote  pristine_48_21.db
# 1124                80    22   3.655674        amniote  pristine_48_22.db
# 1125                80    23   5.125564        amniote  pristine_48_23.db
# 1126                80    24  18.941445        amniote  pristine_48_24.db
# 1127                80     1   2.131084      amphibian   pristine_49_1.db
# 1128                80     2  16.119937      amphibian   pristine_49_2.db
# 1129                80     3   2.766267      amphibian   pristine_49_3.db
# 1130                80     4   8.508750      amphibian   pristine_49_4.db
# 1131                80     5  18.225811      amphibian   pristine_49_5.db
# 1132                80     6  19.340737      amphibian   pristine_49_6.db
# 1133                80     7  16.824312      amphibian   pristine_49_7.db
# 1134                80     8   0.690367      amphibian   pristine_49_8.db
# 1135                80     9   7.681397      amphibian   pristine_49_9.db
# 1136                80    10   6.710675      amphibian  pristine_49_10.db
# 1137                80    11   1.337784      amphibian  pristine_49_11.db
# 1138                80    12   4.724173      amphibian  pristine_49_12.db
# 1139                80    13  15.739642      amphibian  pristine_49_13.db
# 1140                80    14  11.861039      amphibian  pristine_49_14.db
# 1141                80    15  11.164857      amphibian  pristine_49_15.db
# 1142                80    16  14.419014      amphibian  pristine_49_16.db
# 1143                80    17  13.086114      amphibian  pristine_49_17.db
# 1144                80    18  10.162626      amphibian  pristine_49_18.db
# 1145                80    19  15.130138      amphibian  pristine_49_19.db
# 1146                80    20   9.336330      amphibian  pristine_49_20.db
# 1147                80    21  12.418583      amphibian  pristine_49_21.db
# 1148                80    22   3.655674      amphibian  pristine_49_22.db
# 1149                80    23   5.125564      amphibian  pristine_49_23.db
# 1150                80    24  18.941445      amphibian  pristine_49_24.db
#
# [1151 rows x 10 columns]

# %%
tmp_df["exists"] = tmp_df.apply(lambda x : pathlib.Path(results_dir, x["filename"]).exists(), axis=1)

# %%
tmp_df[tmp_df.exists == False]
# Out:
#       density_per_km    interval  job_type output_directory   pbs  \
# 95         45.863370  bashkirian         6           none/6   100
# 97         89.141170  bashkirian         6           none/6   102
# 98        476.047838  bashkirian         6           none/6   103
# 99        944.345234  bashkirian         6           none/6   104
# 100       134.240159  bashkirian         6           none/6   105
# 101        26.429407  bashkirian         6           none/6   106
# 102       342.571843  bashkirian         6           none/6   107
# 103       258.848859  bashkirian         6           none/6   108
# 104        53.290374  bashkirian         6           none/6   109
# 105       706.745869  bashkirian         6           none/6   110
# 106        34.424688  bashkirian         6           none/6   111
# 107        69.095997  bashkirian         6           none/6   112
# 109       101.868488  bashkirian         6           none/6   114
# 110       300.588978  bashkirian         6           none/6   115
# 111        40.402603  bashkirian         6           none/6   116
# 112       205.256155  bashkirian         6           none/6   117
# 114       813.124660  bashkirian         6           none/6   119
# 115       491.604989  bashkirian         6           none/6   120
# 116        30.381943  bashkirian         6           none/6   121
# 117       396.589951  bashkirian         6           none/6   122
# 118        74.277955  bashkirian         6           none/6   123
# 383        45.863370  artinskian        18          none/18   400
# 384       121.998706  artinskian        18          none/18   401
# 385        89.141170  artinskian        18          none/18   402
# 386       476.047838  artinskian        18          none/18   403
# 387       944.345234  artinskian        18          none/18   404
# 388       134.240159  artinskian        18          none/18   405
# 389        26.429407  artinskian        18          none/18   406
# 390       342.571843  artinskian        18          none/18   407
# 391       258.848859  artinskian        18          none/18   408
# ...              ...         ...       ...              ...   ...
# 1121      571.069857   sakmarian        48          none/48  1168
# 1122      813.124660   sakmarian        48          none/48  1169
# 1123      491.604989   sakmarian        48          none/48  1170
# 1124       30.381943   sakmarian        48          none/48  1171
# 1125      396.589951   sakmarian        48          none/48  1172
# 1126       74.277955   sakmarian        48          none/48  1173
# 1127       45.863370   sakmarian        49          none/49  1175
# 1128      121.998706   sakmarian        49          none/49  1176
# 1129       89.141170   sakmarian        49          none/49  1177
# 1130      476.047838   sakmarian        49          none/49  1178
# 1131      944.345234   sakmarian        49          none/49  1179
# 1132      134.240159   sakmarian        49          none/49  1180
# 1133       26.429407   sakmarian        49          none/49  1181
# 1134      342.571843   sakmarian        49          none/49  1182
# 1135      258.848859   sakmarian        49          none/49  1183
# 1136       53.290374   sakmarian        49          none/49  1184
# 1137      706.745869   sakmarian        49          none/49  1185
# 1138       34.424688   sakmarian        49          none/49  1186
# 1139       69.095997   sakmarian        49          none/49  1187
# 1140      177.335194   sakmarian        49          none/49  1188
# 1141      101.868488   sakmarian        49          none/49  1189
# 1142      300.588978   sakmarian        49          none/49  1190
# 1143       40.402603   sakmarian        49          none/49  1191
# 1144      205.256155   sakmarian        49          none/49  1192
# 1145      571.069857   sakmarian        49          none/49  1193
# 1146      813.124660   sakmarian        49          none/49  1194
# 1147      491.604989   sakmarian        49          none/49  1195
# 1148       30.381943   sakmarian        49          none/49  1196
# 1149      396.589951   sakmarian        49          none/49  1197
# 1150       74.277955   sakmarian        49          none/49  1198
#
#       proportion_cover  seed      sigma tetrapod_group           filename  \
# 95                  20     1   2.131084        amniote    pristine_6_1.db
# 97                  20     3   2.766267        amniote    pristine_6_3.db
# 98                  20     4   8.508750        amniote    pristine_6_4.db
# 99                  20     5  18.225811        amniote    pristine_6_5.db
# 100                 20     6  19.340737        amniote    pristine_6_6.db
# 101                 20     7  16.824312        amniote    pristine_6_7.db
# 102                 20     8   0.690367        amniote    pristine_6_8.db
# 103                 20     9   7.681397        amniote    pristine_6_9.db
# 104                 20    10   6.710675        amniote   pristine_6_10.db
# 105                 20    11   1.337784        amniote   pristine_6_11.db
# 106                 20    12   4.724173        amniote   pristine_6_12.db
# 107                 20    13  15.739642        amniote   pristine_6_13.db
# 109                 20    15  11.164857        amniote   pristine_6_15.db
# 110                 20    16  14.419014        amniote   pristine_6_16.db
# 111                 20    17  13.086114        amniote   pristine_6_17.db
# 112                 20    18  10.162626        amniote   pristine_6_18.db
# 114                 20    20   9.336330        amniote   pristine_6_20.db
# 115                 20    21  12.418583        amniote   pristine_6_21.db
# 116                 20    22   3.655674        amniote   pristine_6_22.db
# 117                 20    23   5.125564        amniote   pristine_6_23.db
# 118                 20    24  18.941445        amniote   pristine_6_24.db
# 383                 40     1   2.131084        amniote   pristine_18_1.db
# 384                 40     2  16.119937        amniote   pristine_18_2.db
# 385                 40     3   2.766267        amniote   pristine_18_3.db
# 386                 40     4   8.508750        amniote   pristine_18_4.db
# 387                 40     5  18.225811        amniote   pristine_18_5.db
# 388                 40     6  19.340737        amniote   pristine_18_6.db
# 389                 40     7  16.824312        amniote   pristine_18_7.db
# 390                 40     8   0.690367        amniote   pristine_18_8.db
# 391                 40     9   7.681397        amniote   pristine_18_9.db
# ...                ...   ...        ...            ...                ...
# 1121                80    19  15.130138        amniote  pristine_48_19.db
# 1122                80    20   9.336330        amniote  pristine_48_20.db
# 1123                80    21  12.418583        amniote  pristine_48_21.db
# 1124                80    22   3.655674        amniote  pristine_48_22.db
# 1125                80    23   5.125564        amniote  pristine_48_23.db
# 1126                80    24  18.941445        amniote  pristine_48_24.db
# 1127                80     1   2.131084      amphibian   pristine_49_1.db
# 1128                80     2  16.119937      amphibian   pristine_49_2.db
# 1129                80     3   2.766267      amphibian   pristine_49_3.db
# 1130                80     4   8.508750      amphibian   pristine_49_4.db
# 1131                80     5  18.225811      amphibian   pristine_49_5.db
# 1132                80     6  19.340737      amphibian   pristine_49_6.db
# 1133                80     7  16.824312      amphibian   pristine_49_7.db
# 1134                80     8   0.690367      amphibian   pristine_49_8.db
# 1135                80     9   7.681397      amphibian   pristine_49_9.db
# 1136                80    10   6.710675      amphibian  pristine_49_10.db
# 1137                80    11   1.337784      amphibian  pristine_49_11.db
# 1138                80    12   4.724173      amphibian  pristine_49_12.db
# 1139                80    13  15.739642      amphibian  pristine_49_13.db
# 1140                80    14  11.861039      amphibian  pristine_49_14.db
# 1141                80    15  11.164857      amphibian  pristine_49_15.db
# 1142                80    16  14.419014      amphibian  pristine_49_16.db
# 1143                80    17  13.086114      amphibian  pristine_49_17.db
# 1144                80    18  10.162626      amphibian  pristine_49_18.db
# 1145                80    19  15.130138      amphibian  pristine_49_19.db
# 1146                80    20   9.336330      amphibian  pristine_49_20.db
# 1147                80    21  12.418583      amphibian  pristine_49_21.db
# 1148                80    22   3.655674      amphibian  pristine_49_22.db
# 1149                80    23   5.125564      amphibian  pristine_49_23.db
# 1150                80    24  18.941445      amphibian  pristine_49_24.db
#
#       exists
# 95     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 109    False
# 110    False
# 111    False
# 112    False
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# ...      ...
# 1121   False
# 1122   False
# 1123   False
# 1124   False
# 1125   False
# 1126   False
# 1127   False
# 1128   False
# 1129   False
# 1130   False
# 1131   False
# 1132   False
# 1133   False
# 1134   False
# 1135   False
# 1136   False
# 1137   False
# 1138   False
# 1139   False
# 1140   False
# 1141   False
# 1142   False
# 1143   False
# 1144   False
# 1145   False
# 1146   False
# 1147   False
# 1148   False
# 1149   False
# 1150   False
#
# [789 rows x 11 columns]

# %%
tmp_df.query("interval == 'sakmarian' and tetrapod_group == 'amphibian'")
# Out:
#       density_per_km   interval  job_type output_directory   pbs  \
# 359        45.863370  sakmarian        17          none/17   375
# 360       121.998706  sakmarian        17          none/17   376
# 361        89.141170  sakmarian        17          none/17   377
# 362       476.047838  sakmarian        17          none/17   378
# 363       944.345234  sakmarian        17          none/17   379
# 364       134.240159  sakmarian        17          none/17   380
# 365        26.429407  sakmarian        17          none/17   381
# 366       342.571843  sakmarian        17          none/17   382
# 367       258.848859  sakmarian        17          none/17   383
# 368        53.290374  sakmarian        17          none/17   384
# 369       706.745869  sakmarian        17          none/17   385
# 370        34.424688  sakmarian        17          none/17   386
# 371        69.095997  sakmarian        17          none/17   387
# 372       177.335194  sakmarian        17          none/17   388
# 373       101.868488  sakmarian        17          none/17   389
# 374       300.588978  sakmarian        17          none/17   390
# 375        40.402603  sakmarian        17          none/17   391
# 376       205.256155  sakmarian        17          none/17   392
# 377       571.069857  sakmarian        17          none/17   393
# 378       813.124660  sakmarian        17          none/17   394
# 379       491.604989  sakmarian        17          none/17   395
# 380        30.381943  sakmarian        17          none/17   396
# 381       396.589951  sakmarian        17          none/17   397
# 382        74.277955  sakmarian        17          none/17   398
# 743        45.863370  sakmarian        33          none/33   775
# 744       121.998706  sakmarian        33          none/33   776
# 745        89.141170  sakmarian        33          none/33   777
# 746       476.047838  sakmarian        33          none/33   778
# 747       944.345234  sakmarian        33          none/33   779
# 748       134.240159  sakmarian        33          none/33   780
# ...              ...        ...       ...              ...   ...
# 761       571.069857  sakmarian        33          none/33   793
# 762       813.124660  sakmarian        33          none/33   794
# 763       491.604989  sakmarian        33          none/33   795
# 764        30.381943  sakmarian        33          none/33   796
# 765       396.589951  sakmarian        33          none/33   797
# 766        74.277955  sakmarian        33          none/33   798
# 1127       45.863370  sakmarian        49          none/49  1175
# 1128      121.998706  sakmarian        49          none/49  1176
# 1129       89.141170  sakmarian        49          none/49  1177
# 1130      476.047838  sakmarian        49          none/49  1178
# 1131      944.345234  sakmarian        49          none/49  1179
# 1132      134.240159  sakmarian        49          none/49  1180
# 1133       26.429407  sakmarian        49          none/49  1181
# 1134      342.571843  sakmarian        49          none/49  1182
# 1135      258.848859  sakmarian        49          none/49  1183
# 1136       53.290374  sakmarian        49          none/49  1184
# 1137      706.745869  sakmarian        49          none/49  1185
# 1138       34.424688  sakmarian        49          none/49  1186
# 1139       69.095997  sakmarian        49          none/49  1187
# 1140      177.335194  sakmarian        49          none/49  1188
# 1141      101.868488  sakmarian        49          none/49  1189
# 1142      300.588978  sakmarian        49          none/49  1190
# 1143       40.402603  sakmarian        49          none/49  1191
# 1144      205.256155  sakmarian        49          none/49  1192
# 1145      571.069857  sakmarian        49          none/49  1193
# 1146      813.124660  sakmarian        49          none/49  1194
# 1147      491.604989  sakmarian        49          none/49  1195
# 1148       30.381943  sakmarian        49          none/49  1196
# 1149      396.589951  sakmarian        49          none/49  1197
# 1150       74.277955  sakmarian        49          none/49  1198
#
#       proportion_cover  seed      sigma tetrapod_group           filename  \
# 359                 20     1   2.131084      amphibian   pristine_17_1.db
# 360                 20     2  16.119937      amphibian   pristine_17_2.db
# 361                 20     3   2.766267      amphibian   pristine_17_3.db
# 362                 20     4   8.508750      amphibian   pristine_17_4.db
# 363                 20     5  18.225811      amphibian   pristine_17_5.db
# 364                 20     6  19.340737      amphibian   pristine_17_6.db
# 365                 20     7  16.824312      amphibian   pristine_17_7.db
# 366                 20     8   0.690367      amphibian   pristine_17_8.db
# 367                 20     9   7.681397      amphibian   pristine_17_9.db
# 368                 20    10   6.710675      amphibian  pristine_17_10.db
# 369                 20    11   1.337784      amphibian  pristine_17_11.db
# 370                 20    12   4.724173      amphibian  pristine_17_12.db
# 371                 20    13  15.739642      amphibian  pristine_17_13.db
# 372                 20    14  11.861039      amphibian  pristine_17_14.db
# 373                 20    15  11.164857      amphibian  pristine_17_15.db
# 374                 20    16  14.419014      amphibian  pristine_17_16.db
# 375                 20    17  13.086114      amphibian  pristine_17_17.db
# 376                 20    18  10.162626      amphibian  pristine_17_18.db
# 377                 20    19  15.130138      amphibian  pristine_17_19.db
# 378                 20    20   9.336330      amphibian  pristine_17_20.db
# 379                 20    21  12.418583      amphibian  pristine_17_21.db
# 380                 20    22   3.655674      amphibian  pristine_17_22.db
# 381                 20    23   5.125564      amphibian  pristine_17_23.db
# 382                 20    24  18.941445      amphibian  pristine_17_24.db
# 743                 40     1   2.131084      amphibian   pristine_33_1.db
# 744                 40     2  16.119937      amphibian   pristine_33_2.db
# 745                 40     3   2.766267      amphibian   pristine_33_3.db
# 746                 40     4   8.508750      amphibian   pristine_33_4.db
# 747                 40     5  18.225811      amphibian   pristine_33_5.db
# 748                 40     6  19.340737      amphibian   pristine_33_6.db
# ...                ...   ...        ...            ...                ...
# 761                 40    19  15.130138      amphibian  pristine_33_19.db
# 762                 40    20   9.336330      amphibian  pristine_33_20.db
# 763                 40    21  12.418583      amphibian  pristine_33_21.db
# 764                 40    22   3.655674      amphibian  pristine_33_22.db
# 765                 40    23   5.125564      amphibian  pristine_33_23.db
# 766                 40    24  18.941445      amphibian  pristine_33_24.db
# 1127                80     1   2.131084      amphibian   pristine_49_1.db
# 1128                80     2  16.119937      amphibian   pristine_49_2.db
# 1129                80     3   2.766267      amphibian   pristine_49_3.db
# 1130                80     4   8.508750      amphibian   pristine_49_4.db
# 1131                80     5  18.225811      amphibian   pristine_49_5.db
# 1132                80     6  19.340737      amphibian   pristine_49_6.db
# 1133                80     7  16.824312      amphibian   pristine_49_7.db
# 1134                80     8   0.690367      amphibian   pristine_49_8.db
# 1135                80     9   7.681397      amphibian   pristine_49_9.db
# 1136                80    10   6.710675      amphibian  pristine_49_10.db
# 1137                80    11   1.337784      amphibian  pristine_49_11.db
# 1138                80    12   4.724173      amphibian  pristine_49_12.db
# 1139                80    13  15.739642      amphibian  pristine_49_13.db
# 1140                80    14  11.861039      amphibian  pristine_49_14.db
# 1141                80    15  11.164857      amphibian  pristine_49_15.db
# 1142                80    16  14.419014      amphibian  pristine_49_16.db
# 1143                80    17  13.086114      amphibian  pristine_49_17.db
# 1144                80    18  10.162626      amphibian  pristine_49_18.db
# 1145                80    19  15.130138      amphibian  pristine_49_19.db
# 1146                80    20   9.336330      amphibian  pristine_49_20.db
# 1147                80    21  12.418583      amphibian  pristine_49_21.db
# 1148                80    22   3.655674      amphibian  pristine_49_22.db
# 1149                80    23   5.125564      amphibian  pristine_49_23.db
# 1150                80    24  18.941445      amphibian  pristine_49_24.db
#
#       exists
# 359     True
# 360     True
# 361     True
# 362     True
# 363     True
# 364     True
# 365     True
# 366     True
# 367     True
# 368     True
# 369     True
# 370     True
# 371     True
# 372     True
# 373     True
# 374     True
# 375     True
# 376     True
# 377     True
# 378     True
# 379     True
# 380     True
# 381     True
# 382     True
# 743    False
# 744    False
# 745    False
# 746    False
# 747    False
# 748    False
# ...      ...
# 761    False
# 762    False
# 763    False
# 764    False
# 765    False
# 766    False
# 1127   False
# 1128   False
# 1129   False
# 1130   False
# 1131   False
# 1132   False
# 1133   False
# 1134   False
# 1135   False
# 1136   False
# 1137   False
# 1138   False
# 1139   False
# 1140   False
# 1141   False
# 1142   False
# 1143   False
# 1144   False
# 1145   False
# 1146   False
# 1147   False
# 1148   False
# 1149   False
# 1150   False
#
# [72 rows x 11 columns]

# %%
tmp_output = []
for file in tqdm_notebook(os.listdir(results_dir), desc="Files"):
    file_path = os.path.join(results_dir, file)
    _, ext = os.path.splitext(file_path)
    if ".db" == ext:
        # print(file)
        t = CoalescenceTree(file_path)
        sim_params = t.get_simulation_parameters()
        (interval, tet_group) = sim_type_detection(sim_params["sample_file"])
        scenario = sim_scenario_detection(file)
        if scenario == "clustered": 
            tmp_output.append({"interval" : interval, "tetrapod_group": tet_group, "file" : pathlib.Path(file).name, "seed" : sim_params["seed"],
                              "job_type": sim_params["job_type"]})
# Out:
# HBox(children=(IntProgress(value=0, description='Files', max=1112, style=ProgressStyle(description_width='init…

# %%
pd.DataFrame(tmp_output).groupby(["interval", "tetrapod_group"]).agg(["count"])
# Out:
#                            file job_type  seed
#                           count    count count
# interval   tetrapod_group
# artinskian amniote           24       24    24
#            amphibian         24       24    24
# asselian   amphibian         24       24    24
# gzhelian   amniote           24       24    24
#            amphibian         24       24    24
# kasimovian amniote           15       15    15
# kungurian  amniote           24       24    24
#            amphibian         24       24    24
# moscovian  amniote            3        3     3
#            amphibian         24       24    24
# sakmarian  amniote           24       24    24
#            amphibian         24       24    24
